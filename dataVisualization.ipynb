# %% [markdown]
# ### ***Visualize pickle file generated from rPPG pipeline***

# %%
# Read pickle file and show the contents

import pickle
import sys
import os
import matplotlib.pyplot as plt

def read_pickle_file(file_path):
    """Read a pickle file and return the contents."""
    if not os.path.exists(file_path):
        print(f"File {file_path} does not exist.")
        return None

    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    
    return data

data = read_pickle_file("/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/runs/exp/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/UBFC-rPPG_DeepPhys_PURE_outputs.pickle")
print(data.keys())
# print(data['predictions'].keys())
# plt.plot(data['predictions']['1001'][0])
# plt.show()
# print(data['labels'].keys())
# print(data['labels']['1001'][0].shape)
# plt.plot(data['labels']['1001'][0].flatten())
# plt.show()
print(data['spo2_labels']['1001'][0])
# Out:
# dict_keys(['predictions', 'labels', 'label_type', 'fs', 'spo2_labels'])
# tensor([[96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
#         [96.],
# ...

# %% [markdown]
# ### ***Visualize all labels/ppg signal generated using rPPG in a folder***

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
i = 0
folder = '/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse'  # Replace with your folder path
# for file in [f for f in os.listdir(folder) if f.endswith('.npy') and 'label' in f]:
#     i += 1
#     if i < 10:
#         continue
#     if i > 11:
#         break
#     # data = np.load(os.path.join(folder, file))
data = np.load('/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_label0.npy')
plt.figure()
plt.plot(data)
# plt.title(file)
plt.title('101_label0')
plt.show()

data = np.load('/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions0.npy')
plt.figure()
plt.plot(data)
# plt.title(file)
plt.title('101_predictions0')
plt.show()

# %%
import numpy as np
import os

# Read npy file and show the contents
def read_npy_file(file_path):
    """Read a npy file and return the contents."""
    if not os.path.exists(file_path):
        print(f"File {file_path} does not exist.")
        return None

    data = np.load(file_path)
    
    return data

data = read_npy_file("/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_spo20.npy")
# temp = []
# for i in range(1,7):
#     for j in range(0,20):
#         # print("i: ", i, " j: ", j)
#         data = read_npy_file("/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/80"+str(i)+"_spo2"+str(j)+".npy")
#         if data is not None:
#             for k in data:
#                 temp.append(k)
# print(np.unique(temp))
print(data)
# Out:
# [96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.
#  96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96. 96.]
