# %%
# Read pickle file and show the contents

import pickle
import sys
import os
import matplotlib.pyplot as plt

def read_pickle_file(file_path):
    """Read a pickle file and return the contents."""
    if not os.path.exists(file_path):
        print(f"File {file_path} does not exist.")
        return None

    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    
    return data

data = read_pickle_file("/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/runs/exp/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/UBFC-rPPG_DeepPhys_PURE_outputs.pickle")
print(data.keys())
print(data['labels'])
# print(data['predictions'])
# # # plt.plot(data['predictions']['1001'][0])
# # # plt.show()
# print(data['labels'].keys())
# print(data['labels']['1001'][0].shape)
# plt.plot(data['labels']['1001'][0].flatten())
# plt.show()
# Out:
# dict_keys(['predictions', 'labels', 'label_type', 'fs', 'spo2_labels'])
# {'1001': {0: tensor([[-0.5829],
#         [-0.3514],
#         [-0.1199],
#         [-0.1171],
#         [ 1.1229],
#         [ 2.3080],
#         [ 2.6704],
#         [ 1.3616],
#         [-0.2810],
#         [-1.2428],
#         [-1.1781],
#         [-0.8295],
#         [-0.3997],
#         [-0.0179],
#         [ 0.2135],
#         [ 0.1378],
#         [-0.2108],
#         [-0.5594],
#         [-0.6738],
#         [-0.6986],
#         [-0.6986],
#         [-0.3776],
#         [-0.1779],
#         [-0.1171],
#         [ 0.0826],
#         [ 0.9545],
#         [ 2.1411],
#         [ 2.4085],
#         [ 1.2435],
#         [-0.3398],
#         [-1.1229],
#         [-1.2085],
#         [-0.7884],
#         [-0.3254],
#         [ 0.0000],
#         [ 0.1845],
#         [ 0.1668],
#         [-0.2464],
#         [-0.5829],
#         [-0.6448],
#         [-0.8157],
#         [-0.5223],
#         [-0.4080],
#         [-0.1765],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.6565],
#         [ 1.9465],
#         [ 2.4458],
#         [ 1.6504],
#         [-0.0872],
#         [-1.1365],
#         [-1.2375],
#         [-1.0060],
#         [-0.4607],
#         [ 0.0782],
#         [ 0.2699],
#         [ 0.2773],
#         [-0.1857],
#         [-0.4657],
#         [-0.7315],
#         [-0.8157],
#         [-0.5527],
#         [-0.4384],
#         [-0.2329],
#         [-0.0911],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.1990],
#         [ 1.3974],
#         [ 2.3464],
#         [ 2.3628],
#         [ 0.6920],
#         [-0.7543],
#         [-1.3972],
#         [-1.2693],
#         [-0.7847],
#         [-0.2074],
#         [ 0.2462],
#         [ 0.5762],
#         [ 0.2198],
#         [-0.3550],
#         [-0.6986],
#         [-0.8155],
#         [-0.8160],
#         [-0.5815],
#         [-0.2389],
#         [-0.1215],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.2144],
#         [ 1.6751],
#         [ 2.4092],
#         [ 2.2509],
#         [ 0.4778],
#         [-0.8530],
#         [-1.3804],
#         [-1.1825],
#         [-0.7796],
#         [-0.1604],
#         [ 0.2329],
#         [ 0.4420],
#         [ 0.1673],
#         [-0.2957],
#         [-0.6707],
#         [-0.9022],
#         [-0.8143],
#         [-0.6469],
#         [-0.2662],
#         [-0.1519],
#         [ 0.0000],
#         [ 0.1953],
#         [ 1.2393],
#         [ 2.2481],
#         [ 2.5629],
#         [ 1.2786],
#         [-0.4307],
#         [-1.1885],
#         [-1.2115],
#         [-0.9129],
#         [-0.4499],
#         [ 0.0131],
#         [ 0.2959],
#         [ 0.1698],
#         [-0.1822],
#         [-0.4657],
#         [-0.7575],
#         [-0.8157],
#         [-0.6439],
#         [-0.4657],
#         [-0.2446],
#         [-0.1171],
#         [ 0.6467],
#         [ 1.9400],
#         [ 2.4923],
#         [ 1.8495],
#         [-0.0321],
#         [-1.0598],
#         [-1.2391],
#         [-1.0077],
#         [-0.5827],
#         [-0.0789],
#         [ 0.1880],
#         [ 0.3146],
#         [-0.0667],
#         [-0.3813],
#         [-0.6427],
#         [-0.7858],
#         [-0.6715],
#         [-0.4657],
#         [-0.3242],
#         [ 0.2795],
#         [ 1.7179],
#         [ 2.4660],
#         [ 2.0594],
#         [ 0.2424],
#         [-0.9811],
#         [-1.2654],
#         [-1.1510],
#         [-0.5443],
#         [-0.0946],
#         [ 0.2421],
#         [ 0.3408],
#         [-0.0142],
#         [-0.4671],
#         [-0.5916],
#         [-0.6986],
#         [-0.6986],
#         [-0.4653],
#         [-0.3500],
#         [ 0.4537],
#         [ 1.8454],
#         [ 2.3181],
#         [ 1.8957],
#         [ 0.0618],
#         [-1.0209],
#         [-1.2815],
#         [-1.1772],
#         [-0.4916]]), 1: tensor([[-4.4244e-02],
#         [ 3.4999e-01],
#         [ 4.4869e-01],
#         [-6.0453e-02],
#         [-4.4593e-01],
#         [-6.7741e-01],
#         [-6.9861e-01],
#         [-6.0681e-01],
#         [-4.6574e-01],
#         [-2.5958e-01],
#         [ 3.5197e-01],
#         [ 1.5676e+00],
#         [ 2.2978e+00],
#         [ 1.8775e+00],
#         [ 2.7171e-01],
#         [-9.4222e-01],
#         [-1.2437e+00],
#         [-1.1241e+00],
#         [-4.6742e-01],
#         [ 3.4699e-02],
#         [ 3.0671e-01],
#         [ 3.9328e-01],
#         [-1.4354e-01],
#         [-4.1969e-01],
#         [-5.3405e-01],
#         [-6.9861e-01],
#         [-6.3305e-01],
#         [-4.0156e-01],
#         [-2.3287e-01],
#         [ 7.0839e-03],
#         [ 9.4444e-01],
#         [ 1.8645e+00],
#         [ 2.0385e+00],
#         [ 1.0032e+00],
#         [-5.0818e-01],
#         [-1.1017e+00],
#         [-1.1126e+00],
#         [-7.8037e-01],
#         [-1.8388e-01],
#         [ 1.6473e-01],
#         [ 3.4999e-01],
#         [ 7.0899e-02],
#         [-2.0405e-01],
#         [-5.0782e-01],
#         [-6.9861e-01],
#         [-6.5928e-01],
#         [-4.6574e-01],
#         [-3.1205e-01],
#         [-8.0564e-02],
#         [ 3.3799e-02],
#         [ 7.7875e-01],
#         [ 1.9264e+00],
#         [ 2.1833e+00],
#         [ 1.3136e+00],
#         [-3.7010e-01],
#         [-9.5699e-01],
#         [-1.1161e+00],
#         [-6.9861e-01],
#         [-4.0024e-01],
#         [ 1.9991e-02],
#         [ 2.3287e-01],
#         [ 9.8514e-02],
#         [-1.4882e-01],
#         [-4.6574e-01],
#         [-5.9595e-01],
#         [-6.9861e-01],
#         [-5.6083e-01],
#         [-3.4105e-01],
#         [-1.1712e-01],
#         [ 0.0000e+00],
#         [ 4.8026e-03],
#         [ 7.2532e-01],
#         [ 1.8670e+00],
#         [ 2.3267e+00],
#         [ 1.1645e+00],
#         [-3.4291e-01],
#         [-1.0430e+00],
#         [-1.0521e+00],
#         [-8.2059e-01],
#         [-2.4536e-01],
#         [-7.6242e-03],
#         [ 2.2386e-01],
#         [ 2.3287e-01],
#         [-2.0934e-01],
#         [-4.5259e-01],
#         [-6.8408e-01],
#         [-6.9861e-01],
#         [-4.8303e-01],
#         [-3.6866e-01],
#         [-2.3287e-01],
#         [-2.1432e-02],
#         [ 0.0000e+00],
#         [ 1.8310e-01],
#         [ 1.1508e+00],
#         [ 2.0419e+00],
#         [ 2.1255e+00],
#         [ 8.2335e-01],
#         [-5.7284e-01],
#         [-1.2490e+00],
#         [-1.1643e+00],
#         [-6.8858e-01],
#         [-1.9036e-01],
#         [ 1.9487e-01],
#         [ 3.4999e-01],
#         [ 1.5789e-01],
#         [-2.6433e-01],
#         [-5.3796e-01],
#         [-7.6944e-01],
#         [-6.7543e-01],
#         [-5.8286e-01],
#         [-2.8192e-01],
#         [-1.6755e-01],
#         [ 6.3935e-02],
#         [ 5.3189e-02],
#         [ 0.0000e+00],
#         [ 5.3321e-01],
#         [ 1.7494e+00],
#         [ 2.3871e+00],
#         [ 1.7049e+00],
#         [-1.4978e-01],
#         [-1.1544e+00],
#         [-1.3457e+00],
#         [-1.1812e+00],
#         [-4.8399e-01],
#         [ 1.4348e-01],
#         [ 4.6574e-01],
#         [ 4.9365e-01],
#         [-4.3224e-02],
#         [-5.0896e-01],
#         [-6.6379e-01],
#         [-8.9239e-01],
#         [-6.6090e-01],
#         [-4.6574e-01],
#         [-2.7873e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 3.0797e-02],
#         [ 1.4516e-01],
#         [ 1.2476e+00],
#         [ 2.2929e+00],
#         [ 2.5762e+00],
#         [ 1.0623e+00],
#         [-7.9142e-01],
#         [-1.4409e+00],
#         [-1.4932e+00],
#         [-1.1079e+00],
#         [-2.7927e-01],
#         [ 4.8273e-01],
#         [ 7.1421e-01],
#         [ 4.2581e-01],
#         [-1.5152e-01],
#         [-6.9861e-01],
#         [-8.2443e-01],
#         [-9.2415e-01],
#         [-6.9861e-01],
#         [-4.5523e-01],
#         [-2.2969e-01],
#         [ 1.8010e-03],
#         [ 1.1616e-01],
#         [ 9.3039e-01],
#         [ 2.2077e+00],
#         [ 2.6763e+00],
#         [ 1.6603e+00],
#         [-3.1151e-01],
#         [-1.3778e+00],
#         [-1.6222e+00],
#         [-1.4171e+00],
#         [-6.2675e-01],
#         [ 3.1259e-01],
#         [ 8.0234e-01],
#         [ 8.1573e-01],
#         [-5.1148e-02],
#         [-6.4464e-01],
#         [-8.1435e-01],
#         [-9.3147e-01],
#         [-8.3740e-01],
#         [-4.8879e-01],
#         [-2.5730e-01],
#         [-2.5814e-02],
#         [ 8.8549e-02]]), 2: tensor([[ 9.9013e-01],
#         [ 2.2075e+00],
#         [ 2.7631e+00],
#         [ 1.6958e+00],
#         [-2.2428e-01],
#         [-1.2091e+00],
#         [-1.5143e+00],
#         [-1.1251e+00],
#         [-5.8598e-01],
#         [ 1.0848e-01],
#         [ 4.6574e-01],
#         [ 3.9376e-01],
#         [-2.5454e-02],
#         [-6.0555e-01],
#         [-6.9861e-01],
#         [-8.8219e-01],
#         [-7.4927e-01],
#         [-4.5409e-01],
#         [-2.3287e-01],
#         [-5.4810e-02],
#         [ 0.0000e+00],
#         [ 8.7570e-01],
#         [ 2.1518e+00],
#         [ 2.6183e+00],
#         [ 1.6068e+00],
#         [-1.4888e-01],
#         [-1.0867e+00],
#         [-1.2302e+00],
#         [-9.0170e-01],
#         [-4.1861e-01],
#         [-6.9999e-02],
#         [ 1.6149e-01],
#         [ 7.2760e-02],
#         [-1.5873e-01],
#         [-4.3044e-01],
#         [-6.9861e-01],
#         [-6.9861e-01],
#         [-6.6253e-01],
#         [-4.6574e-01],
#         [-2.8198e-01],
#         [-3.1938e-02],
#         [-8.5187e-02],
#         [ 4.9725e-01],
#         [ 1.6269e+00],
#         [ 2.3565e+00],
#         [ 1.9192e+00],
#         [ 2.2897e-01],
#         [-8.8393e-01],
#         [-1.1435e+00],
#         [-9.1196e-01],
#         [-5.4522e-01],
#         [-9.8995e-02],
#         [ 1.5368e-02],
#         [ 2.1888e-01],
#         [-1.2973e-01],
#         [-3.7245e-01],
#         [-5.8148e-01],
#         [-6.9861e-01],
#         [-5.8148e-01],
#         [-4.5865e-01],
#         [-3.3997e-01],
#         [ 0.0000e+00],
#         [-1.1712e-01],
#         [ 1.8010e-04],
#         [ 5.8064e-01],
#         [ 1.7384e+00],
#         [ 2.2090e+00],
#         [ 1.7644e+00],
#         [ 4.5505e-02],
#         [-1.0270e+00],
#         [-1.1643e+00],
#         [-8.3470e-01],
#         [-4.8885e-01],
#         [-1.2247e-02],
#         [ 2.1924e-01],
#         [ 2.3287e-01],
#         [-2.0009e-01],
#         [-4.4797e-01],
#         [-5.6233e-01],
#         [-8.1573e-01],
#         [-4.8765e-01],
#         [-4.6574e-01],
#         [-1.6647e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 2.5664e-01],
#         [ 1.4708e+00],
#         [ 2.0285e+00],
#         [ 2.0031e+00],
#         [ 4.8567e-01],
#         [-7.8169e-01],
#         [-1.2815e+00],
#         [-1.0885e+00],
#         [-5.9085e-01],
#         [-4.2623e-02],
#         [ 3.7773e-01],
#         [ 2.7825e-01],
#         [-2.2212e-02],
#         [-3.6806e-01],
#         [-5.8148e-01],
#         [-8.1573e-01],
#         [-6.3515e-01],
#         [-4.0366e-01],
#         [-2.3287e-01],
#         [-5.6431e-02],
#         [ 5.7932e-02],
#         [ 5.9193e-02],
#         [ 2.2068e-01],
#         [ 1.4980e+00],
#         [ 2.0849e+00],
#         [ 1.9564e+00],
#         [ 3.4831e-01],
#         [-8.4479e-01],
#         [-1.2815e+00],
#         [-1.1188e+00],
#         [-5.6485e-01],
#         [-3.0257e-02],
#         [ 2.7423e-01],
#         [ 4.2575e-01],
#         [-7.8583e-02],
#         [-4.2443e-01],
#         [-6.1732e-01],
#         [-8.1435e-01],
#         [-7.4819e-01],
#         [-4.3404e-01],
#         [-2.3287e-01],
#         [-8.6808e-02],
#         [ 0.0000e+00],
#         [ 1.9565e-01],
#         [ 1.3159e+00],
#         [ 2.2598e+00],
#         [ 2.3563e+00],
#         [ 8.7924e-01],
#         [-6.6132e-01],
#         [-1.1643e+00],
#         [-1.1313e+00],
#         [-6.8348e-01],
#         [-3.2112e-01],
#         [ 1.2949e-01],
#         [ 2.2188e-01],
#         [-9.6053e-03],
#         [-3.5822e-01],
#         [-4.7258e-01],
#         [-8.1573e-01],
#         [-8.1573e-01],
#         [-5.7878e-01],
#         [-3.4729e-01],
#         [-2.3287e-01],
#         [-6.0033e-05],
#         [ 1.1430e-01],
#         [ 1.1574e-01],
#         [ 1.3650e+00],
#         [ 2.4277e+00],
#         [ 2.4528e+00],
#         [ 8.9359e-01],
#         [-5.3147e-01],
#         [-1.2704e+00],
#         [-1.0611e+00],
#         [-7.2772e-01],
#         [-2.6475e-01],
#         [-1.8010e-02],
#         [ 1.1574e-01],
#         [ 1.9391e-02],
#         [-3.0707e-01],
#         [-4.6574e-01],
#         [-7.9220e-01],
#         [-7.8944e-01],
#         [-6.0778e-01],
#         [-3.7629e-01],
#         [-1.7524e-01],
#         [ 0.0000e+00],
#         [-8.3926e-02],
#         [ 1.3189e-01],
#         [ 1.1870e+00],
#         [ 2.3739e+00],
#         [ 2.4458e+00],
#         [ 1.0499e+00],
#         [-4.9671e-01],
#         [-1.1971e+00]]), 3: tensor([[-1.2072],
#         [-0.8327],
#         [-0.3255],
#         [ 0.0687],
#         [ 0.2329],
#         [ 0.1669],
#         [-0.3634],
#         [-0.5290],
#         [-0.8157],
#         [-0.8157],
#         [-0.6986],
#         [-0.4661],
#         [-0.2329],
#         [-0.0608],
#         [ 0.0000],
#         [ 0.0522],
#         [ 0.9398],
#         [ 2.2454],
#         [ 2.6787],
#         [ 1.6732],
#         [-0.3196],
#         [-1.2082],
#         [-1.3972],
#         [-1.0396],
#         [-0.3849],
#         [ 0.0397],
#         [ 0.4253],
#         [ 0.2774],
#         [-0.1856],
#         [-0.4986],
#         [-0.7301],
#         [-0.9014],
#         [-0.6986],
#         [-0.5542],
#         [-0.2967],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.1607],
#         [ 0.9600],
#         [ 2.2700],
#         [ 2.7591],
#         [ 1.5966],
#         [-0.3398],
#         [-1.4107],
#         [-1.6180],
#         [-1.2478],
#         [-0.5534],
#         [ 0.2582],
#         [ 0.6986],
#         [ 0.5658],
#         [-0.1248],
#         [-0.7024],
#         [-0.8168],
#         [-0.9315],
#         [-0.8160],
#         [-0.5845],
#         [-0.1232],
#         [-0.1171],
#         [ 0.0000],
#         [ 0.5513],
#         [ 2.1501],
#         [ 2.7731],
#         [ 2.3882],
#         [ 0.2330],
#         [-1.1079],
#         [-1.5991],
#         [-1.3152],
#         [-0.7744],
#         [-0.0406],
#         [ 0.3276],
#         [ 0.5829],
#         [ 0.0727],
#         [-0.5312],
#         [-0.6986],
#         [-0.9914],
#         [-0.8436],
#         [-0.5271],
#         [-0.3821],
#         [-0.1157],
#         [-0.0348],
#         [ 0.2386],
#         [ 1.5971],
#         [ 2.5590],
#         [ 2.8011],
#         [ 1.0769],
#         [-0.6715],
#         [-1.2356],
#         [-1.2575],
#         [-0.8630],
#         [-0.3301],
#         [ 0.0157],
#         [ 0.2329],
#         [ 0.1069],
#         [-0.3561],
#         [-0.5815],
#         [-0.7574],
#         [-0.8143],
#         [-0.6412],
#         [-0.4097],
#         [-0.1782],
#         [-0.0638],
#         [ 0.0000],
#         [ 0.3630],
#         [ 1.7069],
#         [ 2.4229],
#         [ 2.2643],
#         [ 0.5345],
#         [-0.7097],
#         [-1.2815],
#         [-1.0077],
#         [-0.6210],
#         [-0.2751],
#         [ 0.0354],
#         [ 0.1989],
#         [-0.0326],
#         [-0.4124],
#         [-0.5815],
#         [-0.8157],
#         [-0.6986],
#         [-0.5558],
#         [-0.3243],
#         [-0.0928],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0376],
#         [ 1.0561],
#         [ 2.1279],
#         [ 2.3858],
#         [ 1.1726],
#         [-0.5147],
#         [-1.1643],
#         [-1.1552],
#         [-0.7989],
#         [-0.3359],
#         [ 0.1221],
#         [ 0.2329],
#         [ 0.1113],
#         [-0.2345],
#         [-0.5820],
#         [-0.6981],
#         [-0.6986],
#         [-0.6986],
#         [-0.3533],
#         [-0.1293],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.1171],
#         [ 0.3125],
#         [ 1.6666],
#         [ 2.2986],
#         [ 2.0444],
#         [ 0.3725],
#         [-0.9733],
#         [-1.2815],
#         [-1.0698],
#         [-0.6521],
#         [-0.0494],
#         [ 0.3232],
#         [ 0.4657],
#         [-0.0313],
#         [-0.4362],
#         [-0.6677],
#         [-0.6986],
#         [-0.6986],
#         [-0.5008],
#         [-0.2693],
#         [-0.0378],
#         [ 0.0765],
#         [ 0.0406],
#         [ 0.4122],
#         [ 1.5724],
#         [ 2.2392],
#         [ 1.8634],
#         [ 0.3352],
#         [-0.9006],
#         [-1.2815],
#         [-1.1002],
#         [-0.6889],
#         [-0.0474],
#         [ 0.4100]]), 4: tensor([[ 4.0714e-01],
#         [ 1.3207e-03],
#         [-4.6165e-01],
#         [-6.3593e-01],
#         [-8.1435e-01],
#         [-7.1097e-01],
#         [-5.3255e-01],
#         [-1.8394e-01],
#         [-1.1712e-01],
#         [ 1.1712e-01],
#         [ 8.9569e-02],
#         [ 1.0775e+00],
#         [ 2.1061e+00],
#         [ 2.3631e+00],
#         [ 1.1568e+00],
#         [-4.2365e-01],
#         [-1.1643e+00],
#         [-1.1292e+00],
#         [-7.4687e-01],
#         [-2.8390e-01],
#         [ 3.0977e-02],
#         [ 2.3287e-01],
#         [ 5.9313e-02],
#         [-2.5970e-01],
#         [-5.8286e-01],
#         [-7.2406e-01],
#         [-6.9861e-01],
#         [-5.6017e-01],
#         [-3.2868e-01],
#         [-2.1432e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 1.8916e-01],
#         [ 1.5678e+00],
#         [ 2.2362e+00],
#         [ 2.2554e+00],
#         [ 5.2679e-01],
#         [-7.2250e-01],
#         [-1.0472e+00],
#         [-9.2061e-01],
#         [-5.7476e-01],
#         [-2.3089e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [-4.6141e-01],
#         [-4.6574e-01],
#         [-6.9368e-01],
#         [-8.1573e-01],
#         [-4.7342e-01],
#         [-3.5906e-01],
#         [-1.2757e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 1.0116e-01],
#         [ 1.3998e+00],
#         [ 2.1581e+00],
#         [ 2.2705e+00],
#         [ 8.4214e-01],
#         [-7.0689e-01],
#         [-1.0486e+00],
#         [-9.5711e-01],
#         [-6.0850e-01],
#         [-2.8828e-01],
#         [-2.9776e-02],
#         [ 1.1574e-01],
#         [-5.3429e-02],
#         [-3.1607e-01],
#         [-4.6574e-01],
#         [-7.8043e-01],
#         [-6.9861e-01],
#         [-9.3165e-01],
#         [-2.3665e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 8.5649e-01],
#         [ 2.0059e+00],
#         [ 2.5166e+00],
#         [ 1.5012e+00],
#         [-1.6971e-01],
#         [-1.1286e+00],
#         [-1.2695e+00],
#         [-9.8610e-01],
#         [-3.9814e-01],
#         [ 5.9733e-02],
#         [ 2.9122e-01],
#         [ 2.3467e-01],
#         [-1.7272e-01],
#         [-5.2133e-01],
#         [-6.8852e-01],
#         [-7.6290e-01],
#         [-6.4854e-01],
#         [-4.6574e-01],
#         [-1.8418e-01],
#         [-6.9818e-02],
#         [ 1.1712e-01],
#         [ 0.0000e+00],
#         [ 4.1783e-02],
#         [ 2.8427e+00],
#         [ 3.5965e+00],
#         [-1.3567e+00],
#         [-1.4404e+00],
#         [-1.0597e+00],
#         [-2.9824e-01],
#         [ 4.6436e-01],
#         [ 6.6787e-01],
#         [ 1.4342e-01],
#         [-4.3392e-01],
#         [-6.9722e-01],
#         [-9.3147e-01],
#         [-9.0764e-01],
#         [-5.5903e-01],
#         [-3.0647e-01],
#         [-9.7434e-02],
#         [ 9.7434e-02],
#         [ 1.1712e-01],
#         [ 3.2754e-01],
#         [ 1.9224e+00],
#         [ 2.4714e+00],
#         [ 2.3518e+00],
#         [ 3.8277e-01],
#         [-1.0659e+00],
#         [-1.5143e+00],
#         [-1.3854e+00],
#         [-8.0084e-01],
#         [-1.0638e-01],
#         [ 3.5035e-01],
#         [ 5.8112e-01],
#         [ 2.3353e-01],
#         [-4.6370e-01],
#         [-6.9999e-01],
#         [-1.0410e+00],
#         [-8.2089e-01],
#         [-5.8940e-01],
#         [-3.5792e-01],
#         [-1.2643e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 1.1846e+00],
#         [ 2.5022e+00],
#         [ 2.8953e+00],
#         [ 1.5597e+00],
#         [-4.4731e-01],
#         [-1.3348e+00],
#         [-1.4189e+00],
#         [-9.7770e-01],
#         [-5.4060e-01],
#         [ 6.3995e-02],
#         [ 3.2136e-01],
#         [ 2.6150e-01],
#         [-1.7284e-01],
#         [-6.0303e-01],
#         [-6.9722e-01],
#         [-9.3147e-01],
#         [-7.3414e-01],
#         [-5.0266e-01],
#         [-2.7117e-01],
#         [-3.9682e-02],
#         [ 0.0000e+00],
#         [ 7.4735e-01],
#         [ 2.1972e+00],
#         [ 2.8211e+00],
#         [ 1.8898e+00],
#         [-1.1466e-02],
#         [-1.1320e+00],
#         [-1.3972e+00],
#         [-1.0357e+00],
#         [-6.2759e-01],
#         [-1.1112e-01],
#         [ 2.3287e-01],
#         [ 2.9188e-01],
#         [-5.6731e-02],
#         [-4.6069e-01],
#         [-6.9861e-01],
#         [-8.6832e-01],
#         [-7.6314e-01],
#         [-5.3165e-01],
#         [-3.0017e-01],
#         [-6.8678e-02],
#         [ 0.0000e+00]]), 5: tensor([[ 0.7786],
#         [ 2.1102],
#         [ 2.6045],
#         [ 1.7316],
#         [-0.5473],
#         [-1.3972],
#         [-1.2441],
#         [-0.8608],
#         [-0.2475],
#         [ 0.1809],
#         [ 0.4352],
#         [ 0.0866],
#         [-0.3175],
#         [-0.5815],
#         [-0.8407],
#         [-0.7908],
#         [-0.5593],
#         [-0.3278],
#         [-0.2134],
#         [ 0.0000],
#         [ 0.3010],
#         [ 1.6089],
#         [ 2.3426],
#         [ 2.3817],
#         [ 0.7111],
#         [-0.8451],
#         [-1.3972],
#         [-1.2731],
#         [-0.9019],
#         [ 0.0000],
#         [ 0.2400],
#         [ 0.4657],
#         [ 0.2311],
#         [-0.4646],
#         [-0.5841],
#         [-0.8131],
#         [-0.8157],
#         [-0.4711],
#         [-0.3568],
#         [-0.1157],
#         [-0.0095],
#         [ 0.5364],
#         [ 1.9172],
#         [ 2.4171],
#         [ 1.8239],
#         [ 0.1344],
#         [-1.0916],
#         [-1.3007],
#         [-1.1643],
#         [-0.5550],
#         [-0.0234],
#         [ 0.5073],
#         [ 0.4022],
#         [-0.0608],
#         [-0.6409],
#         [-0.6670],
#         [-0.8143],
#         [-0.6489],
#         [-0.3844],
#         [-0.2329],
#         [-0.0372],
#         [-0.0399],
#         [ 1.0392],
#         [ 2.1303],
#         [ 2.4031],
#         [ 1.2867],
#         [-0.4246],
#         [-1.1864],
#         [-1.2125],
#         [-0.7978],
#         [-0.4519],
#         [ 0.1282],
#         [ 0.3500],
#         [-0.0055],
#         [-0.4685],
#         [-0.5815],
#         [-0.8157],
#         [-0.6986],
#         [-0.5278],
#         [-0.2439],
#         [-0.0510],
#         [-0.0662],
#         [ 0.4271],
#         [ 2.8522],
#         [ 2.4458],
#         [ 1.3905],
#         [-0.2589],
#         [-1.0899],
#         [-1.1244],
#         [-0.8544],
#         [-0.4286],
#         [-0.0800],
#         [ 0.1515],
#         [ 0.0827],
#         [-0.2975],
#         [-0.4657],
#         [-0.6406],
#         [-0.7869],
#         [-0.6725],
#         [-0.3486],
#         [-0.2081],
#         [-0.0938],
#         [ 0.0000],
#         [ 0.3495],
#         [ 1.6849],
#         [ 2.3630],
#         [ 2.1047],
#         [ 0.4843],
#         [-0.9575],
#         [-1.1534],
#         [-0.9219],
#         [-0.5733],
#         [-0.2179],
#         [ 0.0054],
#         [ 0.2288],
#         [-0.1198],
#         [-0.3513],
#         [-0.5827],
#         [-0.6986],
#         [-0.8157],
#         [-0.4686],
#         [-0.3543],
#         [-0.1157],
#         [-0.0070],
#         [ 0.0000],
#         [ 0.6469],
#         [ 2.1557],
#         [ 2.3287],
#         [ 1.7025],
#         [-0.1243],
#         [-1.1143],
#         [-1.1643],
#         [-1.0680],
#         [-0.4125],
#         [-0.0222],
#         [ 0.2093],
#         [ 0.2592],
#         [-0.0894],
#         [-0.4380],
#         [-0.7561],
#         [-0.7291],
#         [-0.6147],
#         [-0.4657],
#         [-0.1864],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.2309],
#         [ 1.5035],
#         [ 2.2442],
#         [ 2.2703],
#         [ 0.5901],
#         [-0.8645],
#         [-1.2330],
#         [-1.3299],
#         [-0.7323],
#         [-0.1550],
#         [ 0.2960],
#         [ 0.4657],
#         [ 0.2278],
#         [-0.3523],
#         [-0.6405],
#         [-0.8720],
#         [-0.7595],
#         [-0.5916],
#         [-0.2979],
#         [-0.1171],
#         [ 0.0000],
#         [ 0.4741],
#         [ 1.7486],
#         [ 2.3739],
#         [ 2.0644],
#         [ 0.3563],
#         [-0.9389],
#         [-1.5143],
#         [-1.2418],
#         [-0.7022],
#         [-0.1249],
#         [ 0.3842],
#         [ 0.5501],
#         [ 0.0529]]), 6: tensor([[-0.3800],
#         [-0.7286],
#         [-0.8430],
#         [-0.7885],
#         [-0.5570],
#         [-0.3255],
#         [-0.1157],
#         [-0.0750],
#         [ 0.7170],
#         [ 2.2671],
#         [ 2.7958],
#         [ 1.9596],
#         [ 0.0202],
#         [-1.1764],
#         [-1.3972],
#         [-1.2522],
#         [-0.5656],
#         [-0.1027],
#         [ 0.3552],
#         [ 0.3448],
#         [-0.0086],
#         [-0.4668],
#         [-0.6986],
#         [-0.9311],
#         [-0.8175],
#         [-0.5815],
#         [-0.2419],
#         [-0.1230],
#         [ 0.0000],
#         [ 0.5455],
#         [ 2.1514],
#         [ 2.7588],
#         [ 2.1753],
#         [ 0.1147],
#         [-1.0852],
#         [-1.3972],
#         [-1.0852],
#         [-0.7394],
#         [-0.1593],
#         [ 0.2104],
#         [ 0.3500],
#         [ 0.0252],
#         [-0.5017],
#         [-0.5815],
#         [-0.9021],
#         [-0.7293],
#         [-0.6150],
#         [-0.3835],
#         [-0.1157],
#         [-0.0363],
#         [ 0.2733],
#         [ 1.4713],
#         [ 2.4390],
#         [ 2.5725],
#         [ 0.9741],
#         [-0.7074],
#         [-1.4211],
#         [-1.3274],
#         [-0.9618],
#         [-0.2017],
#         [ 0.2972],
#         [ 0.4570],
#         [-0.3017],
#         [-0.5815],
#         [-0.8745],
#         [-0.8143],
#         [-0.7023],
#         [-0.4111],
#         [-0.1796],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.4798],
#         [ 1.9192],
#         [ 2.6079],
#         [ 2.2904],
#         [ 0.3022],
#         [-0.9845],
#         [-1.5130],
#         [-1.4341],
#         [-0.8159],
#         [-0.0043],
#         [ 0.4206],
#         [ 0.6308],
#         [ 0.1353],
#         [-0.4969],
#         [-0.6986],
#         [-0.8441],
#         [-0.7873],
#         [-0.5558],
#         [-0.3244],
#         [-0.0929],
#         [ 0.0215],
#         [ 0.4304],
#         [ 1.6094],
#         [ 2.4632],
#         [ 2.3326],
#         [ 0.4780],
#         [-0.9857],
#         [-1.6301],
#         [-1.4921],
#         [-0.9029],
#         [-0.2008],
#         [ 0.7063],
#         [ 0.6937],
#         [ 0.3380],
#         [-0.4714],
#         [-0.6986],
#         [-0.8151],
#         [-0.8163],
#         [-0.5848],
#         [-0.3534],
#         [-0.1157],
#         [-0.0061],
#         [ 0.8837],
#         [ 2.1760],
#         [ 2.6684],
#         [ 1.7027],
#         [-0.2430],
#         [-1.2369],
#         [-1.5143],
#         [-1.2986],
#         [-0.4242],
#         [ 0.1717],
#         [ 0.5602],
#         [ 0.4884],
#         [-0.0435],
#         [-0.6477],
#         [-0.7875],
#         [-0.8143],
#         [-0.7282],
#         [-0.3796],
#         [-0.1818],
#         [ 0.0000],
#         [ 0.3225],
#         [ 1.8754],
#         [ 2.4065],
#         [ 2.1791],
#         [ 0.4030],
#         [-0.8791],
#         [-1.2815],
#         [-0.9763],
#         [-0.6752],
#         [-0.2122],
#         [ 0.1839],
#         [ 0.2329],
#         [-0.0124],
#         [-0.4127],
#         [-0.5829],
#         [-0.7599],
#         [-0.6986],
#         [-0.4672],
#         [-0.2329],
#         [-0.0614],
#         [ 0.0000],
#         [ 0.3753],
#         [ 1.6665],
#         [ 2.1949],
#         [ 1.9266],
#         [ 0.3035],
#         [-0.8342],
#         [-1.1210],
#         [-0.8895],
#         [-0.5003],
#         [-0.1937],
#         [ 0.0378],
#         [ 0.0793],
#         [-0.0351],
#         [-0.4174],
#         [-0.5815],
#         [-0.6986],
#         [-0.5815],
#         [-0.5252],
#         [-0.2061],
#         [-0.1171],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.3193],
#         [ 1.2452],
#         [ 2.1342],
#         [ 2.0089]]), 7: tensor([[ 5.8574e-01],
#         [-7.4303e-01],
#         [-1.1514e+00],
#         [-9.1989e-01],
#         [-5.7127e-01],
#         [-2.1384e-01],
#         [ 1.2457e-01],
#         [ 1.1574e-01],
#         [-1.0746e-02],
#         [-3.5329e-01],
#         [-5.8478e-01],
#         [-6.9861e-01],
#         [-6.9861e-01],
#         [-4.6658e-01],
#         [-3.5221e-01],
#         [-1.1574e-01],
#         [ 1.0578e-01],
#         [ 6.3635e-03],
#         [ 1.1712e-01],
#         [ 9.6113e-02],
#         [ 1.2262e+00],
#         [ 2.1759e+00],
#         [ 2.2262e+00],
#         [ 8.1855e-01],
#         [-7.3420e-01],
#         [-1.2641e+00],
#         [-1.1643e+00],
#         [-7.6050e-01],
#         [-1.6023e-01],
#         [ 3.0275e-01],
#         [ 3.7431e-01],
#         [ 1.4282e-01],
#         [-4.1159e-01],
#         [-5.8286e-01],
#         [-7.8589e-01],
#         [-6.9861e-01],
#         [-5.3231e-01],
#         [-2.6823e-01],
#         [-1.1712e-01],
#         [ 1.1712e-01],
#         [ 7.7623e-02],
#         [-3.6740e-02],
#         [ 3.7569e-01],
#         [ 1.6502e+00],
#         [ 2.2400e+00],
#         [ 1.9030e+00],
#         [ 2.1048e-01],
#         [-1.0889e+00],
#         [-1.3972e+00],
#         [-1.2149e+00],
#         [-5.5771e-01],
#         [ 7.1559e-02],
#         [ 5.2679e-01],
#         [ 5.2181e-01],
#         [ 5.6611e-02],
#         [-5.8094e-01],
#         [-7.5414e-01],
#         [-8.7732e-01],
#         [-7.6296e-01],
#         [-5.3147e-01],
#         [-1.8286e-01],
#         [ 0.0000e+00],
#         [ 1.1712e-01],
#         [ 0.0000e+00],
#         [ 4.1219e-01],
#         [ 1.6155e+00],
#         [ 2.4135e+00],
#         [ 2.2427e+00],
#         [ 4.9990e-01],
#         [-9.6743e-01],
#         [-1.3972e+00],
#         [-1.2104e+00],
#         [-7.4747e-01],
#         [-1.3531e-01],
#         [ 2.6355e-01],
#         [ 4.6574e-01],
#         [ 1.4774e-01],
#         [-4.0306e-01],
#         [-7.2376e-01],
#         [-9.3147e-01],
#         [-7.9196e-01],
#         [-5.6047e-01],
#         [-3.2898e-01],
#         [-9.7494e-02],
#         [ 1.6869e-02],
#         [ 1.0026e-01],
#         [ 2.8216e-02],
#         [ 1.0361e+00],
#         [ 2.3514e+00],
#         [ 2.7645e+00],
#         [ 1.5501e+00],
#         [-3.8739e-01],
#         [-1.2873e+00],
#         [-1.2712e+00],
#         [-9.2535e-01],
#         [-3.4693e-01],
#         [-1.1514e-01],
#         [ 2.3287e-01],
#         [ 1.1821e-01],
#         [-2.3041e-01],
#         [-5.7380e-01],
#         [-6.9200e-01],
#         [-8.1435e-01],
#         [-7.0659e-01],
#         [-4.7510e-01],
#         [-2.4361e-01],
#         [-1.2925e-01],
#         [ 1.0224e-01],
#         [ 1.4888e-02],
#         [ 0.0000e+00],
#         [ 9.8094e-02],
#         [ 1.5922e+00],
#         [ 3.7383e+00],
#         [ 2.0687e+00],
#         [-4.4725e-02],
#         [-1.2064e+00],
#         [-1.3074e+00],
#         [-9.8748e-01],
#         [-5.2451e-01],
#         [-3.0077e-02],
#         [ 2.0141e-01],
#         [ 1.4996e-01],
#         [-1.9865e-01],
#         [-5.1028e-01],
#         [-6.9861e-01],
#         [-8.9311e-01],
#         [-7.3835e-01],
#         [-5.0686e-01],
#         [-2.7537e-01],
#         [-1.1574e-01],
#         [ 2.5214e-02],
#         [ 4.6646e-02],
#         [ 0.0000e+00],
#         [-6.6337e-02],
#         [ 1.4408e-01],
#         [ 1.6121e+00],
#         [ 2.6324e+00],
#         [ 2.6669e+00],
#         [ 9.1586e-01],
#         [-8.7450e-01],
#         [-1.5143e+00],
#         [-1.3972e+00],
#         [-9.4732e-01],
#         [-2.4355e-01],
#         [ 2.1942e-01],
#         [ 4.6574e-01],
#         [ 2.0345e-01],
#         [-3.2688e-01],
#         [-6.9861e-01],
#         [-8.5997e-01],
#         [-8.8861e-01],
#         [-6.5712e-01],
#         [-4.2563e-01],
#         [-1.9415e-01],
#         [ 0.0000e+00],
#         [ 3.5960e-02],
#         [ 8.1165e-02],
#         [-3.3198e-02],
#         [-8.3926e-02],
#         [ 7.4243e-01],
#         [ 2.5344e+00],
#         [ 3.0287e+00],
#         [ 2.0630e+00],
#         [-2.9428e-01],
#         [-1.3285e+00],
#         [-1.7251e+00],
#         [-1.3557e+00],
#         [-6.1966e-01],
#         [ 1.5314e-01],
#         [ 5.9949e-01],
#         [ 5.5098e-01],
#         [-4.2984e-02],
#         [-5.9535e-01],
#         [-8.2684e-01],
#         [-9.3147e-01],
#         [-8.0600e-01],
#         [-5.7452e-01],
#         [-3.3745e-01],
#         [ 0.0000e+00],
#         [ 2.8216e-03]]), 8: tensor([[ 1.1430e-01],
#         [ 6.0033e-05],
#         [ 5.8028e-01],
#         [ 2.0838e+00],
#         [ 2.7876e+00],
#         [ 2.2347e+00],
#         [ 1.6767e-01],
#         [-1.2459e+00],
#         [-1.6219e+00],
#         [-1.6301e+00],
#         [-8.5967e-01],
#         [-5.0848e-02],
#         [ 9.7710e-01],
#         [ 6.4337e-01],
#         [-1.8334e-01],
#         [-7.6068e-01],
#         [-8.1435e-01],
#         [-1.0486e+00],
#         [-7.2064e-01],
#         [-5.1394e-01],
#         [-2.5904e-01],
#         [ 0.0000e+00],
#         [ 8.8189e-02],
#         [ 2.8936e-02],
#         [ 5.7596e-01],
#         [ 2.1054e+00],
#         [ 2.9611e+00],
#         [ 2.3053e+00],
#         [ 3.2532e-01],
#         [-1.1312e+00],
#         [-1.3972e+00],
#         [-1.3214e+00],
#         [-8.2407e-01],
#         [-2.0261e-01],
#         [ 3.0587e-01],
#         [ 4.2023e-01],
#         [ 2.4914e-02],
#         [-3.6782e-01],
#         [-8.1573e-01],
#         [-8.8045e-01],
#         [-8.1435e-01],
#         [-5.7332e-01],
#         [-4.0516e-01],
#         [-1.7368e-01],
#         [ 5.7812e-02],
#         [ 5.9313e-02],
#         [ 2.2723e-01],
#         [ 1.4270e+00],
#         [ 2.4869e+00],
#         [ 2.6417e+00],
#         [ 1.0644e+00],
#         [-5.4396e-01],
#         [-1.2593e+00],
#         [-1.1893e+00],
#         [-8.4346e-01],
#         [-3.0599e-01],
#         [-7.4501e-02],
#         [ 1.5699e-01],
#         [ 7.7263e-02],
#         [-3.0845e-01],
#         [-6.1858e-01],
#         [-6.1582e-01],
#         [-8.1435e-01],
#         [-6.6565e-01],
#         [-4.0396e-01],
#         [-2.3287e-01],
#         [-8.8309e-02],
#         [ 1.1712e-01],
#         [ 0.0000e+00],
#         [ 2.3359e-01],
#         [ 1.4862e+00],
#         [ 2.3917e+00],
#         [ 2.3281e+00],
#         [ 6.6943e-01],
#         [-7.4915e-01],
#         [-1.2815e+00],
#         [-1.0200e+00],
#         [-6.7411e-01],
#         [-2.2200e-01],
#         [ 9.4852e-03],
#         [ 2.2476e-01],
#         [-1.3057e-01],
#         [-5.8286e-01],
#         [-5.8682e-01],
#         [-8.1315e-01],
#         [-5.8286e-01],
#         [-4.6574e-01],
#         [-2.3305e-01],
#         [-1.1869e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 8.8621e-01],
#         [ 2.1777e+00],
#         [ 2.5517e+00],
#         [ 1.2569e+00],
#         [-3.7473e-01],
#         [-1.1504e+00],
#         [-1.1643e+00],
#         [-8.4923e-01],
#         [-3.8625e-01],
#         [ 7.6722e-02],
#         [ 2.3287e-01],
#         [ 1.3940e-01],
#         [-1.8418e-01],
#         [-5.5645e-01],
#         [-6.7081e-01],
#         [-7.2640e-01],
#         [-6.1204e-01],
#         [-3.8055e-01],
#         [-1.4906e-01],
#         [-3.4699e-02],
#         [ 3.4699e-02],
#         [ 1.1712e-01],
#         [-7.8283e-02],
#         [ 1.9187e-01],
#         [ 1.6202e+00],
#         [ 2.2441e+00],
#         [ 2.0806e+00],
#         [ 4.7480e-01],
#         [-9.0998e-01],
#         [-1.3501e+00],
#         [-1.2128e+00],
#         [-6.6667e-01],
#         [-5.1268e-02],
#         [ 3.0641e-01],
#         [ 5.1977e-01],
#         [ 1.1082e-01],
#         [-4.1111e-01],
#         [-6.9861e-01],
#         [-8.7192e-01],
#         [-7.5954e-01],
#         [-5.2805e-01],
#         [-2.4451e-01],
#         [-6.6457e-02],
#         [ 6.6457e-02],
#         [ 1.1712e-01],
#         [-4.6526e-02],
#         [ 1.9691e-02],
#         [ 1.2406e+00],
#         [ 2.3401e+00],
#         [ 2.4723e+00],
#         [ 9.6173e-01],
#         [-7.3721e-01],
#         [-1.3183e+00],
#         [-1.3617e+00],
#         [-8.6190e-01],
#         [-2.4908e-01],
#         [ 2.1114e-01],
#         [ 5.5152e-01],
#         [ 1.7434e-01],
#         [-3.1583e-01],
#         [-6.9861e-01],
#         [-8.1573e-01],
#         [-8.1573e-01],
#         [-6.7693e-01],
#         [-3.2832e-01],
#         [-2.1396e-01],
#         [ 0.0000e+00],
#         [ 1.6149e-02],
#         [ 1.0098e-01],
#         [ 1.8406e-01],
#         [ 1.6929e+00],
#         [ 2.5948e+00],
#         [ 2.6112e+00],
#         [ 7.4867e-01],
#         [-8.3656e-01],
#         [-1.2866e+00],
#         [-1.1555e+00],
#         [-8.0733e-01],
#         [-2.3191e-01],
#         [ 1.1670e-01],
#         [ 2.3287e-01],
#         [ 1.8010e-03],
#         [-3.4225e-01],
#         [-6.9404e-01],
#         [-8.0841e-01],
#         [-8.1435e-01],
#         [-6.0027e-01],
#         [-4.6574e-01]]), 9: tensor([[-0.2443],
#         [-0.0128],
#         [ 0.1015],
#         [ 0.0156],
#         [ 0.0000],
#         [ 0.2921],
#         [ 1.8391],
#         [ 2.6350],
#         [ 2.5147],
#         [ 0.4746],
#         [-0.8290],
#         [-1.2815],
#         [-1.0766],
#         [-0.7588],
#         [-0.2637],
#         [-0.0322],
#         [ 0.1993],
#         [-0.0459],
#         [-0.3123],
#         [-0.5829],
#         [-0.8533],
#         [-0.7391],
#         [-0.6986],
#         [-0.4364],
#         [-0.1617],
#         [-0.0474],
#         [ 0.0474],
#         [ 0.0670],
#         [-0.0670],
#         [ 0.7368],
#         [ 2.1800],
#         [ 2.7402],
#         [ 1.9022],
#         [-0.0638],
#         [-1.1633],
#         [-1.3413],
#         [-1.1098],
#         [-0.6548],
#         [-0.0639],
#         [ 0.2847],
#         [ 0.3009],
#         [-0.0953],
#         [-0.5120],
#         [-0.6264],
#         [-0.9315],
#         [-0.7722],
#         [-0.5407],
#         [-0.3092],
#         [-0.1949],
#         [ 0.0366],
#         [ 0.0805],
#         [ 0.0339],
#         [ 0.6295],
#         [ 2.0212],
#         [ 2.7958],
#         [ 2.1290],
#         [ 0.1302],
#         [-1.0997],
#         [-1.5143],
#         [-1.2573],
#         [-0.7272],
#         [-0.0556],
#         [ 0.4844],
#         [ 0.5469],
#         [ 0.0680],
#         [-0.4948],
#         [-0.6972],
#         [-0.9315],
#         [-0.7936],
#         [-0.4657],
#         [-0.3334],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.1206],
#         [ 0.7182],
#         [ 2.0973],
#         [ 2.5616],
#         [ 1.6368],
#         [-0.2172],
#         [-1.2664],
#         [-1.3972],
#         [-1.1781],
#         [-0.4898],
#         [ 0.0979],
#         [ 0.5608],
#         [ 0.3734],
#         [-0.0896],
#         [-0.6697],
#         [-0.6814],
#         [-0.9315],
#         [-0.6201],
#         [-0.4657],
#         [-0.1371],
#         [-0.0228],
#         [ 0.0000],
#         [ 0.5952],
#         [ 1.9613],
#         [ 2.5050],
#         [ 1.9279],
#         [ 0.1029],
#         [-0.9500],
#         [-1.2815],
#         [-1.0838],
#         [-0.5389],
#         [-0.0759],
#         [ 0.1935],
#         [ 0.2329],
#         [-0.1052],
#         [-0.4657],
#         [-0.6538],
#         [-0.8157],
#         [-0.6986],
#         [-0.4480],
#         [-0.2329],
#         [-0.0517],
#         [ 0.0000],
#         [ 0.1784],
#         [ 1.1203],
#         [ 2.0384],
#         [ 2.4474],
#         [ 1.1816],
#         [-0.3902],
#         [-1.0486],
#         [-0.9970],
#         [-0.6484],
#         [-0.4169],
#         [-0.0683],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.2775],
#         [-0.5090],
#         [-0.6234],
#         [-0.6986],
#         [-0.5437],
#         [-0.4294],
#         [-0.1979],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0309],
#         [ 0.4679],
#         [ 1.6281],
#         [ 2.2397],
#         [ 1.9171],
#         [ 0.2035],
#         [-0.8383],
#         [-1.0486],
#         [-0.7747],
#         [-0.4473],
#         [-0.2158],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.1300],
#         [-0.3730],
#         [-0.5815],
#         [-0.6986],
#         [-0.6912],
#         [-0.4657],
#         [-0.3394],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.1148],
#         [ 1.1479],
#         [ 2.0885],
#         [ 2.3301],
#         [ 0.8621],
#         [-0.6504],
#         [-1.1552],
#         [-0.9420],
#         [-0.7106],
#         [-0.2595],
#         [ 0.1024],
#         [ 0.2168],
#         [ 0.0175],
#         [-0.3109],
#         [-0.5829],
#         [-0.6770],
#         [-0.6986],
#         [-0.4901]])}, '1002': {0: tensor([[-0.1330],
#         [ 0.9092],
#         [ 2.3506],
#         [ 3.0202],
#         [ 2.1683],
#         [ 0.0926],
#         [-1.1466],
#         [-1.3194],
#         [-0.9599],
#         [-0.6806],
#         [-0.1771],
#         [-0.1330],
#         [-0.1044],
#         [-0.3969],
#         [-0.8629],
#         [-1.0224],
#         [-0.8269],
#         [-0.6982],
#         [-0.3035],
#         [-0.1308],
#         [-0.1771],
#         [ 0.6043],
#         [ 2.0817],
#         [ 2.9320],
#         [ 2.3548],
#         [ 0.3901],
#         [-0.9409],
#         [-1.1885],
#         [-0.9172],
#         [-0.4608],
#         [-0.1992],
#         [ 0.0000],
#         [-0.0603],
#         [-0.9122],
#         [-0.9247],
#         [-0.8710],
#         [-0.6093],
#         [-0.3969],
#         [-0.0837],
#         [ 0.0000],
#         [ 0.1280],
#         [ 1.3931],
#         [ 2.4919],
#         [ 2.7944],
#         [ 1.1749],
#         [-0.6904],
#         [-1.5854],
#         [-1.2921],
#         [-0.8473],
#         [ 0.0479],
#         [ 0.4382],
#         [ 0.4887],
#         [-0.0347],
#         [-0.4109],
#         [-0.6608],
#         [-0.4043],
#         [-0.7916],
#         [-0.6586],
#         [-0.7916],
#         [-0.7924],
#         [-0.7922],
#         [ 0.7774],
#         [ 2.7479],
#         [ 3.0356],
#         [ 1.3981],
#         [-0.5951],
#         [-1.3069],
#         [-1.0701],
#         [-0.8275],
#         [-0.2829],
#         [ 0.1118],
#         [ 0.2404],
#         [-0.0795],
#         [-0.4698],
#         [-1.0254],
#         [-1.1541],
#         [-0.8605],
#         [-0.5644],
#         [-0.2108],
#         [ 0.0898],
#         [ 1.1883],
#         [ 2.7207],
#         [ 3.3848],
#         [ 2.1198],
#         [-0.1609],
#         [-1.4203],
#         [-1.5089],
#         [-1.3194],
#         [-0.8435],
#         [-0.3270],
#         [-0.0653],
#         [-0.1964],
#         [-0.3861],
#         [-0.8505],
#         [-0.9224],
#         [-0.8680],
#         [-0.7393],
#         [-0.3446],
#         [-0.2160],
#         [ 0.8976],
#         [ 2.5944],
#         [ 3.5634],
#         [ 2.8908],
#         [ 0.5862],
#         [-1.0286],
#         [-1.7163],
#         [-1.5227],
#         [-1.0274],
#         [-0.4738],
#         [-0.1308],
#         [-0.2853],
#         [-0.5470],
#         [-0.9247],
#         [-0.7916],
#         [-0.6460],
#         [-0.3843],
#         [-0.2639],
#         [-0.1128],
#         [ 1.0827],
#         [ 2.6479],
#         [ 3.0350],
#         [ 1.7255],
#         [-0.3729],
#         [-1.6940],
#         [-1.7235],
#         [-1.2074],
#         [-0.4318],
#         [ 0.2362],
#         [ 0.3787],
#         [-0.0761],
#         [-0.7507],
#         [-0.8998],
#         [-0.9495],
#         [-0.6878],
#         [-0.4262],
#         [-0.1645],
#         [ 0.1943],
#         [ 1.7247],
#         [ 2.8264],
#         [ 2.7639],
#         [ 0.6506],
#         [-1.1799],
#         [-1.8471],
#         [-1.4175],
#         [-0.7351],
#         [ 0.0238],
#         [ 0.6051],
#         [ 0.3218],
#         [-0.2144],
#         [-0.7293],
#         [-0.9247],
#         [-0.8605],
#         [-0.5989],
#         [-0.3969],
#         [-0.0158],
#         [ 1.0501],
#         [ 2.5363],
#         [ 3.0356],
#         [ 1.7992],
#         [-0.2833],
#         [-1.5874],
#         [-1.8960],
#         [-1.1997],
#         [-0.2817],
#         [ 0.4324],
#         [ 0.5943],
#         [ 0.0000],
#         [-0.4568],
#         [-0.7141],
#         [-0.8980],
#         [-0.6363],
#         [-0.3747],
#         [-0.2460],
#         [ 0.3442],
#         [ 1.7856],
#         [ 2.9272],
#         [ 2.7042],
#         [ 0.7327],
#         [-1.0761],
#         [-1.8447]]), 1: tensor([[-1.5828],
#         [-0.7934],
#         [ 0.1206],
#         [ 0.2681],
#         [ 0.0150],
#         [-0.3969],
#         [-0.7700],
#         [-0.9247],
#         [-0.5430],
#         [-0.5277],
#         [-0.1723],
#         [ 1.0290],
#         [ 2.5403],
#         [ 3.1402],
#         [ 1.7129],
#         [-0.3088],
#         [-1.3845],
#         [-1.5832],
#         [-1.0365],
#         [-0.3845],
#         [ 0.0892],
#         [ 0.1769],
#         [-0.3025],
#         [-0.6608],
#         [-0.9545],
#         [-0.9773],
#         [-0.5826],
#         [-0.3210],
#         [ 0.1553],
#         [ 1.6760],
#         [ 2.7730],
#         [ 2.7088],
#         [ 0.8133],
#         [-0.8445],
#         [-1.1885],
#         [-1.1885],
#         [-0.8147],
#         [-0.3430],
#         [-0.1649],
#         [-0.0968],
#         [-0.4420],
#         [-0.8796],
#         [-1.0555],
#         [-0.8840],
#         [-0.5860],
#         [-0.2298],
#         [ 0.6221],
#         [ 2.2021],
#         [ 2.9322],
#         [ 2.3268],
#         [ 0.2290],
#         [-1.1202],
#         [-1.5832],
#         [-1.2679],
#         [-0.6159],
#         [ 0.1451],
#         [ 0.3871],
#         [-0.0076],
#         [-0.4077],
#         [-0.6618],
#         [-0.9214],
#         [-0.7916],
#         [-0.6620],
#         [-0.2729],
#         [ 0.7592],
#         [ 2.2105],
#         [ 2.8948],
#         [ 1.7796],
#         [-0.2771],
#         [-1.4003],
#         [-1.4712],
#         [-1.0998],
#         [-0.4434],
#         [ 0.0799],
#         [ 0.1607],
#         [-0.2020],
#         [-0.4935],
#         [-0.7916],
#         [-0.9247],
#         [-0.6994],
#         [-0.6608],
#         [-0.3069],
#         [ 0.7341],
#         [ 2.2660],
#         [ 2.6884],
#         [ 1.8201],
#         [-0.0679],
#         [-1.2813],
#         [-1.5109],
#         [-0.9759],
#         [-0.2589],
#         [ 0.0657],
#         [ 0.2639],
#         [ 0.0082],
#         [-0.9142],
#         [-0.7916],
#         [-0.7369],
#         [-0.6083],
#         [-0.3969],
#         [-0.1196],
#         [ 1.1563],
#         [ 2.3772],
#         [ 2.5972],
#         [ 1.5285],
#         [-0.3576],
#         [-1.3542],
#         [-1.4175],
#         [-0.9315],
#         [-0.3404],
#         [ 0.1569],
#         [ 0.2140],
#         [-0.0433],
#         [-0.5472],
#         [-0.7916],
#         [-0.7916],
#         [-0.7788],
#         [-0.5171],
#         [-0.2386],
#         [ 0.9641],
#         [ 2.3851],
#         [ 2.7699],
#         [ 1.7117],
#         [-0.2567],
#         [-1.3141],
#         [-1.5784],
#         [-0.9457],
#         [-0.2937],
#         [ 0.2388],
#         [ 0.1445],
#         [ 0.0339],
#         [-0.3767],
#         [-0.6608],
#         [-0.5524],
#         [-0.3969],
#         [-0.3969],
#         [-0.0603],
#         [ 1.3935],
#         [ 2.5027],
#         [ 2.2558],
#         [ 0.5712],
#         [-1.0260],
#         [-1.6740],
#         [-1.4105],
#         [-0.5370],
#         [ 0.1150],
#         [ 0.3150],
#         [ 0.1088],
#         [-0.3392],
#         [-0.7339],
#         [-0.9956],
#         [-0.8537],
#         [-0.5921],
#         [ 0.4546],
#         [ 2.1621],
#         [ 3.0845],
#         [ 2.4366],
#         [ 0.3432],
#         [-1.1643],
#         [-1.4524],
#         [-1.2216],
#         [-0.5652],
#         [-0.0864],
#         [ 0.0423],
#         [-0.1224],
#         [-0.5277],
#         [-0.8295],
#         [-0.9247],
#         [-0.8934],
#         [-0.6027],
#         [ 0.8800],
#         [ 2.5003],
#         [ 3.3854],
#         [ 2.2085],
#         [ 0.1513],
#         [-1.0735],
#         [-1.1885],
#         [-0.8996],
#         [-0.3855],
#         [-0.1238],
#         [ 0.0000]]), 10: tensor([[-7.9161e-01],
#         [-6.1931e-01],
#         [-2.4644e-01],
#         [ 1.4826e-01],
#         [ 2.5085e-01],
#         [ 0.0000e+00],
#         [-1.5027e-01],
#         [-3.9470e-01],
#         [-5.2353e-01],
#         [-3.9691e-01],
#         [-1.3103e-01],
#         [-1.3304e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 7.6216e-01],
#         [ 1.3103e+00],
#         [ 1.4524e+00],
#         [ 7.1668e-01],
#         [-3.4782e-01],
#         [-7.7378e-01],
#         [-8.1385e-01],
#         [-4.1915e-01],
#         [-1.5748e-01],
#         [ 1.3304e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [-9.7574e-02],
#         [-3.9691e-01],
#         [-3.9691e-01],
#         [-2.6387e-01],
#         [-1.7511e-01],
#         [-1.3304e-01],
#         [-1.3304e-01],
#         [ 8.2147e-02],
#         [ 8.4972e-01],
#         [ 1.3971e+00],
#         [ 1.5652e+00],
#         [ 6.2912e-01],
#         [-3.4642e-01],
#         [-7.9161e-01],
#         [-7.2489e-01],
#         [-4.6323e-01],
#         [-2.0156e-01],
#         [ 6.0107e-02],
#         [ 7.2930e-02],
#         [-1.3304e-01],
#         [-3.1957e-01],
#         [-3.1516e-01],
#         [-4.7865e-01],
#         [-3.9691e-01],
#         [-1.3083e-01],
#         [-2.2140e-01],
#         [-4.0272e-02],
#         [ 1.1641e-01],
#         [ 9.0141e-01],
#         [ 1.3530e+00],
#         [ 1.4889e+00],
#         [ 5.7082e-01],
#         [-3.4722e-01],
#         [-9.2465e-01],
#         [-7.6897e-01],
#         [-3.7427e-01],
#         [-2.4564e-01],
#         [ 1.6029e-02],
#         [ 1.1701e-01],
#         [-1.1621e-02],
#         [-3.8749e-01],
#         [-4.1354e-01],
#         [-5.2273e-01],
#         [-2.6387e-01],
#         [-2.6327e-01],
#         [ 0.0000e+00],
#         [-1.3304e-01],
#         [ 1.2703e-01],
#         [ 9.0442e-01],
#         [ 1.4233e+00],
#         [ 1.4732e+00],
#         [ 4.4740e-01],
#         [-4.8326e-01],
#         [-7.7458e-01],
#         [-6.8001e-01],
#         [-4.1835e-01],
#         [-1.5668e-01],
#         [ 0.0000e+00],
#         [ 1.3304e-01],
#         [-1.3304e-01],
#         [-2.3141e-01],
#         [-4.9308e-01],
#         [-3.9470e-01],
#         [-4.3598e-01],
#         [-3.9691e-01],
#         [-1.3083e-01],
#         [-1.7872e-01],
#         [ 0.0000e+00],
#         [ 5.8905e-01],
#         [ 1.4001e+00],
#         [ 1.6618e+00],
#         [ 1.0206e+00],
#         [-9.7975e-02],
#         [-7.9161e-01],
#         [-7.9161e-01],
#         [-6.6098e-01],
#         [-2.0076e-01],
#         [ 0.0000e+00],
#         [ 1.3304e-01],
#         [-5.6501e-02],
#         [-2.6387e-01],
#         [-4.4900e-01],
#         [-5.2774e-01],
#         [-5.2774e-01],
#         [-3.4922e-01],
#         [-2.2059e-01],
#         [-4.1073e-02],
#         [-5.3095e-02],
#         [ 4.7024e-01],
#         [ 1.2941e+00],
#         [ 1.7163e+00],
#         [ 1.3300e+00],
#         [ 1.5027e-01],
#         [-6.8643e-01],
#         [-9.2465e-01],
#         [-6.3734e-01],
#         [-3.5664e-01],
#         [ 0.0000e+00],
#         [ 1.3304e-01],
#         [-1.2422e-02],
#         [-2.6387e-01],
#         [-2.7189e-01],
#         [-5.2774e-01],
#         [-3.9110e-01],
#         [-2.6387e-01],
#         [-2.6387e-01],
#         [-8.0143e-04],
#         [-1.2783e-01],
#         [ 1.2042e-01],
#         [ 1.0236e+00],
#         [ 2.2388e+00],
#         [ 1.0932e+00],
#         [ 5.8304e-02],
# ...
#         [-5.6562e-02],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-1.7262e-01],
#         [-7.0029e-02],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [-2.4265e-01],
#         [ 6.9588e-01],
#         [ 2.3783e+00],
#         [ 3.6724e+00],
#         [ 3.4319e+00],
#         [ 1.4689e+00],
#         [-5.1787e-01],
#         [-1.2079e+00],
#         [-8.3300e-01],
#         [-4.8261e-01],
#         [-4.8261e-01],
#         [-4.8261e-01],
#         [-1.1851e-01],
#         [ 0.0000e+00],
#         [-3.5872e-01],
#         [-8.3864e-01],
#         [-1.2079e+00],
#         [-9.6523e-01],
#         [-5.1200e-01],
#         [-3.4525e-01],
#         [-3.8271e-01],
#         [-2.4265e-01],
#         [-9.4515e-02],
#         [-2.3996e-01],
#         [-2.3996e-01],
#         [-3.9618e-01],
#         [-3.2639e-01],
#         [-2.3996e-01],
#         [-2.3996e-01],
#         [-1.6430e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [-6.4887e-02],
#         [-1.7777e-01],
#         [-2.4265e-01],
#         [ 5.6807e-02],
#         [ 9.4172e-01],
#         [ 2.8100e+00],
#         [ 3.8122e+00],
#         [ 2.7089e+00],
#         [ 5.4652e-01],
#         [-1.0086e+00],
#         [-9.2727e-01],
#         [-4.8261e-01],
#         [-5.1518e-01],
#         [-7.2257e-01],
#         [-4.5274e-01],
#         [-2.1547e-01],
#         [-2.6445e-01],
#         [-7.2527e-01],
#         [-9.8433e-01],
#         [-9.5152e-01],
#         [-4.8261e-01],
#         [-4.7429e-01],
#         [-2.4265e-01],
#         [-2.4265e-01]]), 6: tensor([[-0.2427],
#         [-0.2402],
#         [-0.2400],
#         [-0.2478],
#         [-0.4748],
#         [-0.2400],
#         [-0.2559],
#         [-0.2427],
#         [-0.2214],
#         [-0.0213],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.2079],
#         [-0.2774],
#         [-0.2427],
#         [ 0.8421],
#         [ 2.5245],
#         [ 3.3328],
#         [ 2.5605],
#         [ 0.5000],
#         [-0.9116],
#         [-0.9652],
#         [-0.7843],
#         [-0.6609],
#         [-0.7226],
#         [-0.5497],
#         [-0.0698],
#         [-0.4101],
#         [-0.4826],
#         [-0.8874],
#         [-0.9652],
#         [-0.5659],
#         [-0.4826],
#         [-0.0886],
#         [ 0.0000],
#         [-0.2427],
#         [ 0.0000],
#         [-0.1405],
#         [-0.1021],
#         [-0.2427],
#         [-0.2427],
#         [-0.1298],
#         [-0.2400],
#         [-0.2400],
#         [-0.1183],
#         [ 0.2427],
#         [ 0.0000],
#         [ 0.2427],
#         [ 0.1109],
#         [ 0.1317],
#         [-0.1055],
#         [-0.1371],
#         [ 0.4429],
#         [ 1.8403],
#         [ 3.3279],
#         [ 3.4341],
#         [ 1.7209],
#         [-0.5054],
#         [-1.1239],
#         [-0.7253],
#         [-0.2400],
#         [-0.4826],
#         [-0.7253],
#         [-0.4121],
#         [-0.2427],
#         [-0.0651],
#         [-0.4826],
#         [-0.8448],
#         [-0.9055],
#         [-0.6682],
#         [-0.2400],
#         [-0.2400],
#         [-0.4363],
#         [-0.2862],
#         [-0.2400],
#         [-0.4444],
#         [-0.2782],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.2206],
#         [-0.0167],
#         [-0.2120],
#         [ 0.2287],
#         [-0.0086],
#         [-0.2341],
#         [-0.2458],
#         [-0.2395],
#         [ 0.0000],
#         [ 1.1937],
#         [ 2.8783],
#         [ 3.8533],
#         [ 2.6996],
#         [ 0.5372],
#         [-0.9339],
#         [-0.9863],
#         [-0.4826],
#         [-0.0238],
#         [-0.4562],
#         [-0.2718],
#         [-0.0345],
#         [ 0.0345],
#         [-0.4454],
#         [-0.6827],
#         [-0.9652],
#         [-0.5759],
#         [-0.4346],
#         [-0.4826],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.3041],
#         [-0.4185],
#         [-0.4826],
#         [-0.2400],
#         [-0.2400],
#         [-0.0749],
#         [-0.2427],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.1462],
#         [-0.0965],
#         [ 0.2816],
#         [ 1.6222],
#         [ 2.9265],
#         [ 3.3783],
#         [ 1.8702],
#         [-0.1420],
#         [-1.2079],
#         [-0.8433],
#         [-0.4826],
#         [-0.3661],
#         [-0.3565],
#         [-0.1288],
#         [ 0.0000],
#         [-0.1058],
#         [-0.4826],
#         [-0.7253],
#         [-0.8230],
#         [-0.5326],
#         [-0.3350],
#         [-0.2400],
#         [-0.1530],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [-0.3161],
#         [-0.1692],
#         [-0.2427],
#         [-0.2427],
#         [ 0.0000],
#         [-0.2427],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.2427],
#         [ 0.0000],
#         [ 0.6087],
#         [ 2.0100],
#         [ 3.2125],
#         [ 3.0365],
#         [ 1.2933],
#         [-0.7529],
#         [-1.1829],
#         [-0.4826],
#         [-0.2400],
#         [-0.2400],
#         [-0.4826],
#         [-0.2285],
#         [ 0.0000],
#         [-0.0061],
#         [-0.4860]]), 7: tensor([[-0.9645],
#         [-0.7233],
#         [-0.7226],
#         [-0.4873],
#         [-0.0073],
#         [-0.2299],
#         [-0.2400],
#         [-0.2400],
#         [-0.4826],
#         [-0.2635],
#         [-0.4591],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.0424],
#         [ 0.0000],
#         [-0.2427],
#         [-0.4322],
#         [-0.4826],
#         [-0.2400],
#         [ 0.7285],
#         [ 2.4055],
#         [ 3.3117],
#         [ 3.0982],
#         [ 1.0744],
#         [-0.5786],
#         [-0.9652],
#         [-0.3974],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [ 0.1518],
#         [ 0.0908],
#         [-0.1464],
#         [-0.6263],
#         [-0.9652],
#         [-0.8269],
#         [-0.7253],
#         [-0.1070],
#         [ 0.0000],
#         [-0.1276],
#         [-0.1151],
#         [-0.1222],
#         [-0.2400],
#         [-0.3658],
#         [-0.3568],
#         [-0.3712],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.2427],
#         [-0.0899],
#         [-0.1528],
#         [ 0.8232],
#         [ 2.5793],
#         [ 3.4601],
#         [ 3.0727],
#         [ 0.9104],
#         [-0.7963],
#         [-0.8969],
#         [-0.4826],
#         [-0.2400],
#         [-0.4826],
#         [-0.4251],
#         [-0.2427],
#         [ 0.0000],
#         [-0.2921],
#         [-0.5294],
#         [-0.9652],
#         [-0.7226],
#         [-0.6839],
#         [-0.4466],
#         [-0.2760],
#         [-0.2400],
#         [-0.2120],
#         [-0.2679],
#         [-0.2400],
#         [-0.4826],
#         [-0.2400],
#         [-0.4826],
#         [-0.2400],
#         [-0.2400],
#         [-0.4762],
#         [-0.2463],
#         [-0.2400],
#         [-0.4826],
#         [-0.2400],
#         [-0.7182],
#         [-0.4897],
#         [-0.7253],
#         [ 0.2150],
#         [ 1.6244],
#         [ 3.7867],
#         [ 3.8815],
#         [ 2.2921],
#         [-0.1075],
#         [-1.1765],
#         [-0.9966],
#         [-0.2740],
#         [-0.0367],
#         [-0.2427],
#         [-0.2427],
#         [ 0.2427],
#         [ 0.0000],
#         [-0.4324],
#         [-0.9123],
#         [-0.9652],
#         [-0.7835],
#         [-0.6616],
#         [-0.3036],
#         [-0.3090],
#         [-0.1709],
#         [-0.2400],
#         [-0.2400],
#         [-0.2400],
#         [-0.4826],
#         [-0.7253],
#         [-0.4826],
#         [-0.4826],
#         [-0.4826],
#         [-0.4826],
#         [-0.0960],
#         [-0.2427],
#         [ 0.0000],
#         [-0.1359],
#         [-0.1068],
#         [ 0.3732],
#         [ 1.4792],
#         [ 3.5164],
#         [ 4.2260],
#         [ 3.2595],
#         [ 0.6173],
#         [-0.9540],
#         [-1.2052],
#         [-0.8536],
#         [-0.6163],
#         [-0.2400],
#         [-0.1391],
#         [ 0.2427],
#         [ 0.0000],
#         [-0.4283],
#         [-0.9652],
#         [-1.2079],
#         [-0.9652],
#         [-0.3979],
#         [-0.4033],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [-0.0686],
#         [-0.4167],
#         [-0.3058],
#         [-0.4826],
#         [-0.2400],
#         [-0.4826],
#         [-0.2400],
#         [-0.1903],
#         [-0.0470],
#         [-0.1956],
#         [-0.2843],
#         [-0.2400],
#         [-0.2037],
#         [ 0.3433],
#         [ 2.2992],
#         [ 3.6491],
#         [ 3.7845],
#         [ 1.7911],
#         [-0.5228],
#         [-1.4305],
#         [-0.9505],
#         [-0.2400],
#         [-0.2400],
#         [-0.4826],
#         [-0.4787]]), 8: tensor([[ 0.0000e+00],
#         [-2.4118e-01],
#         [-7.2110e-01],
#         [-9.6523e-01],
#         [-9.6523e-01],
#         [-7.2257e-01],
#         [-4.9486e-01],
#         [-2.5759e-01],
#         [-2.2233e-01],
#         [-2.0323e-02],
#         [-2.4265e-01],
#         [-2.1425e-01],
#         [-2.7106e-01],
#         [-4.5152e-01],
#         [-2.3996e-01],
#         [-4.8261e-01],
#         [-2.3996e-01],
#         [-4.1871e-02],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [-1.8732e-01],
#         [-5.5338e-02],
#         [-2.4265e-01],
#         [ 1.7924e-01],
#         [ 1.4975e+00],
#         [ 3.1800e+00],
#         [ 3.8636e+00],
#         [ 2.2933e+00],
#         [-1.7385e-02],
#         [-1.0514e+00],
#         [-8.8442e-01],
#         [-3.2493e-01],
#         [-3.9765e-01],
#         [-4.8261e-01],
#         [-2.3996e-01],
#         [-9.3046e-02],
#         [-1.4422e-01],
#         [-4.8261e-01],
#         [-8.6410e-01],
#         [-9.6523e-01],
#         [-8.3178e-01],
#         [-4.8261e-01],
#         [-4.8261e-01],
#         [-2.3996e-01],
#         [-4.8261e-01],
#         [-3.6263e-01],
#         [-6.0259e-01],
#         [-5.9721e-01],
#         [-7.2257e-01],
#         [-6.1337e-01],
#         [-3.7610e-01],
#         [-2.4265e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 9.5739e-02],
#         [ 3.8957e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 8.4965e-02],
#         [ 2.3996e-01],
#         [ 9.6400e-01],
#         [ 2.6464e+00],
#         [ 3.7693e+00],
#         [ 3.5722e+00],
#         [ 1.3411e+00],
#         [-6.8364e-01],
#         [-1.1418e+00],
#         [-9.0450e-01],
#         [-2.3996e-01],
#         [-5.3795e-01],
#         [-6.1728e-01],
#         [-2.4265e-01],
#         [-4.7257e-02],
#         [-2.8452e-01],
#         [-9.6523e-01],
#         [-1.0044e+00],
#         [-1.1322e+00],
#         [-4.8261e-01],
#         [-4.8261e-01],
#         [-2.3996e-01],
#         [-2.3996e-01],
#         [-2.1694e-01],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-4.1626e-03],
#         [-2.3849e-01],
#         [-2.4143e-01],
#         [-1.2243e-03],
#         [-2.4265e-01],
#         [ 0.0000e+00],
#         [-2.4265e-01],
#         [-4.7062e-01],
#         [-4.8261e-01],
#         [-2.6004e-01],
#         [ 9.0230e-01],
#         [ 3.0446e+00],
#         [ 4.0499e+00],
#         [ 3.6773e+00],
#         [ 1.1530e+00],
#         [-6.2194e-01],
#         [-1.2079e+00],
#         [-5.6317e-01],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-4.3560e-01],
#         [-2.9236e-01],
#         [ 0.0000e+00],
#         [-1.8487e-01],
#         [-9.0744e-01],
#         [-9.6523e-01],
#         [-9.6523e-01],
#         [-7.9113e-01],
#         [-3.1121e-01],
#         [-4.1136e-01],
#         [-2.3996e-01],
#         [-2.3996e-01],
#         [-7.9334e-02],
#         [-2.4265e-01],
#         [-2.4265e-01],
#         [-3.9520e-01],
#         [-2.3996e-01],
#         [-3.3545e-01],
#         [-2.4265e-01],
#         [-1.4177e-01],
#         [-1.0088e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [-1.2831e-01],
#         [-2.3996e-01],
#         [-1.1704e-01],
#         [ 6.0333e-01],
#         [ 2.5284e+00],
#         [ 3.8533e+00],
#         [ 3.2818e+00],
#         [ 1.0284e+00],
#         [-9.3878e-01],
#         [-1.2052e+00],
#         [-1.0024e+00],
#         [-4.8261e-01],
#         [-4.8261e-01],
#         [-1.4667e-01],
#         [ 2.4265e-01],
#         [ 1.5475e-01],
#         [-3.2517e-01],
#         [-9.6523e-01],
#         [-1.0451e+00],
#         [-1.0509e+00],
#         [-4.8261e-01],
#         [-4.1087e-01],
#         [-2.4265e-01],
#         [ 0.0000e+00],
#         [-2.4265e-01],
#         [-6.0969e-02],
#         [-4.2434e-01],
#         [-2.9824e-01],
#         [-2.3996e-01],
#         [-4.3242e-01],
#         [-2.9016e-01],
#         [-1.9515e-01],
#         [-2.4265e-01],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [ 0.0000e+00],
#         [-2.4265e-01],
#         [-2.7130e-01],
#         [-2.3996e-01],
#         [-1.9344e-01],
#         [ 1.0708e+00],
#         [ 3.1741e+00],
#         [ 4.3462e+00],
#         [ 3.3132e+00],
#         [ 6.7091e-01],
#         [-1.2150e+00],
#         [-1.1964e+00]]), 9: tensor([[-0.4826],
#         [-0.2409],
#         [-0.4816],
#         [-0.4826],
#         [-0.2400],
#         [-0.0091],
#         [-0.4709],
#         [-0.9508],
#         [-0.9652],
#         [-0.9652],
#         [-0.7478],
#         [-0.2679],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [-0.4412],
#         [-0.4826],
#         [-0.4826],
#         [-0.0495],
#         [-0.2427],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.0656],
#         [-0.1770],
#         [-0.2427],
#         [-0.4116],
#         [-0.4826],
#         [ 0.0872],
#         [ 1.0470],
#         [ 2.8085],
#         [ 4.3301],
#         [ 3.5769],
#         [ 1.1773],
#         [-0.9275],
#         [-1.3031],
#         [-0.8232],
#         [-0.4826],
#         [-0.4826],
#         [-0.4826],
#         [-0.1087],
#         [ 0.0000],
#         [-0.3685],
#         [-0.6058],
#         [-1.2079],
#         [-0.9652],
#         [-0.6075],
#         [-0.3702],
#         [-0.2427],
#         [-0.1070],
#         [-0.1357],
#         [-0.2427],
#         [-0.2427],
#         [-0.3389],
#         [-0.2400],
#         [-0.3918],
#         [-0.2427],
#         [-0.2427],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.0720],
#         [-0.2400],
#         [-0.4160],
#         [ 0.0000],
#         [ 0.7914],
#         [ 2.7728],
#         [ 3.9753],
#         [ 3.3499],
#         [ 0.9503],
#         [-1.0634],
#         [-1.4028],
#         [-0.9652],
#         [-0.6829],
#         [-0.4826],
#         [-0.2057],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.2951],
#         [-0.9652],
#         [-0.9860],
#         [-1.1689],
#         [-0.4826],
#         [-0.2400],
#         [-0.2299],
#         [-0.2427],
#         [ 0.0000],
#         [-0.2427],
#         [-0.2419],
#         [-0.2400],
#         [-0.2461],
#         [-0.4765],
#         [-0.2400],
#         [-0.2400],
#         [-0.0142],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.2150],
#         [-0.0277],
#         [-0.2427],
#         [-0.0357],
#         [ 1.3379],
#         [ 3.2630],
#         [ 4.3051],
#         [ 3.0299],
#         [ 0.2818],
#         [-1.1068],
#         [-1.4478],
#         [-0.8345],
#         [-0.4826],
#         [-0.7253],
#         [-0.3053],
#         [-0.2427],
#         [ 0.0000],
#         [-0.5810],
#         [-0.9652],
#         [-0.9652],
#         [-1.0468],
#         [-0.4826],
#         [-0.4826],
#         [-0.0869],
#         [-0.2427],
#         [-0.1476],
#         [-0.2400],
#         [-0.2400],
#         [-0.3430],
#         [-0.2427],
#         [-0.2427],
#         [-0.3741],
#         [-0.1112],
#         [-0.2427],
#         [ 0.0000],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.3580],
#         [-0.3700],
#         [ 0.2199],
#         [ 2.1222],
#         [ 3.4520],
#         [ 4.1398],
#         [ 2.0553],
#         [-0.3886],
#         [-1.4478],
#         [-1.3568],
#         [-0.7226],
#         [-0.6369],
#         [-0.2400],
#         [ 0.0830],
#         [ 0.2427],
#         [-0.3176],
#         [-0.5548],
#         [-1.0348],
#         [-1.1383],
#         [-0.4799],
#         [-0.4185],
#         [-0.2400],
#         [-0.1839],
#         [ 0.0000],
#         [-0.2427],
#         [-0.2427],
#         [-0.2880],
#         [-0.2400],
#         [-0.4427],
#         [-0.2427],
#         [-0.2427],
#         [-0.2427],
#         [ 0.0000],
#         [ 0.0000],
#         [-0.0238],
#         [-0.2189],
#         [-0.2427],
#         [ 0.5480],
#         [ 2.2120],
#         [ 3.8842],
#         [ 4.0705],
#         [ 1.6557]])}}

# %%
import os
import numpy as np
import pandas as pd
import antropy as ant
import neurokit2 as nk
import heartpy as hp
import logging
import warnings

logging.basicConfig(level=logging.INFO)

def compute_statistical(signal):
    """Compute 9 statistical features"""
    return {
        'mean': np.nanmean(signal),
        'min': np.nanmin(signal),
        'max': np.nanmax(signal),
        'std': np.nanstd(signal),
        'dynamic_range': np.ptp(signal),
        'p10': np.nanpercentile(signal, 10),
        'p25': np.nanpercentile(signal, 25),
        'p75': np.nanpercentile(signal, 75),
        'p90': np.nanpercentile(signal, 90)
    }

def compute_fractal(signal, sf=30):
    """Compute 6 fractal features"""
    try:
        sub_windows = [signal[i:i+60] for i in range(0, 180, 60)]
        return {
            'katz': ant.katz_fd(signal),
            'higuchi': ant.higuchi_fd(signal),
            'dfa': ant.detrended_fluctuation(signal),
            'mean_katz': np.mean([ant.katz_fd(sw) for sw in sub_windows]),
            'mean_higuchi': np.mean([ant.higuchi_fd(sw) for sw in sub_windows]),
            'mean_dfa': np.mean([ant.detrended_fluctuation(sw) for sw in sub_windows])
        }
    except Exception as e:
        logging.warning(f"Fractal computation error: {str(e)}")
        return {}

def compute_entropy(signal, sf=30):
    """Compute 6 entropy features"""
    try:
        return {
            'perm_entropy': ant.perm_entropy(signal, normalize=True),
            'spectral_entropy': ant.spectral_entropy(signal, sf, method='welch'),
            'approx_entropy': ant.app_entropy(signal), 
            'sample_entropy': ant.sample_entropy(signal),
            'hjorth_mobility': ant.hjorth_params(signal)[0],
            'hjorth_complexity': ant.hjorth_params(signal)[1]
        }
    except Exception as e:
        logging.warning(f"Entropy computation error: {str(e)}")
        return {}
    
def calculate_hrv_time_features(signal, sf=30, selected_feat = None):
    """Compute given time-domain HRV features"""
    try:
        signals, info = nk.ppg_process(signal, sampling_rate=sf)
        nn_intervals = np.diff(info["PPG_Peaks"]) / sf * 1000 
        hrv = nk.hrv_time(info["PPG_Peaks"], sampling_rate=sf)
        return {feature: hrv[feature].values[0] for feature in selected_feat if feature in hrv.columns}
        
    except Exception as e:
        logging.warning(f"HRV time features computation error: {str(e)}")
        return {}
    
# def calculate_hrv_frequency_features(signal, sf=30): Not implemented because of short signal length
# def calculate_hrv_nonlinear_features(signal, sf=30): Not implemented because of some error of short signal length. A part of it can be implemented removing the error
    

def process_file(file_path):
    try:
        signal = np.load(file_path).flatten()
        if len(signal) != 180:
            raise ValueError("Signal length must be 180 samples")
            
        features = {}
        features['filename'] = file_path
        features.update(compute_statistical(signal))
        features.update(compute_fractal(signal))
        features.update(compute_entropy(signal))
        selected_hrv_time_features = ['HRV_RMSSD', 'HRV_SDSD', 'HRV_pNN50', 'HRV_pNN20','HRV_HTI']
        # selected_hrv_freq_features = [f for f in selected_hrv_time_features if f in nk.hrv_time(signal).columns]
        # selected_hrv_nonLin_features = [f for f in selected_hrv_time_features if f in nk.hrv_time(signal).columns]
        features.update(calculate_hrv_time_features(signal, selected_feat = selected_hrv_time_features))
        return features
    except Exception as e:
        logging.error(f"Error processing {file_path}: {str(e)}")
        return {}

# %% [markdown]
# ### ***Saving predictions from pickle to numpy***

# %%
import os
import numpy as np
import pickle

# Path to the pickle file
pickle_file_path = "/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/runs/exp/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/UBFC-rPPG_DeepPhys_PURE_outputs.pickle"

# Folder to save the npy files
save_folder = "/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse"

# Function to load the pickle file
def read_pickle_file(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# Load data
data = read_pickle_file(pickle_file_path)

# Process and save each 180-length prediction vector
for subject_id in data['predictions'].keys():
    for segment_id in data['predictions'][subject_id].keys():
        vector = data['predictions'][subject_id][segment_id]
        
        # Convert to numpy array
        vector = np.array(vector)
        
        # Construct the filename
        filename = f"{subject_id}_predictions{segment_id}.npy"
        save_path = os.path.join(save_folder, filename)
        
        # Save to file
        np.save(save_path, vector)

        print(f"Saved: {save_path}")
# Out:
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1001_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1002_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions11.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1003_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions11.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1004_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1005_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/1006_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/101_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/102_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions11.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions12.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/103_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions11.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions12.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/104_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/105_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/106_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/201_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/202_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/203_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/203_predictions1.npy
# ...
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/902_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/902_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/902_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/902_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/902_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions11.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/903_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions11.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions12.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions13.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/904_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/905_predictions9.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions0.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions1.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions10.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions2.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions3.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions4.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions5.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions6.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions7.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions8.npy
# Saved: /home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/906_predictions9.npy

# %%
output_ppg_files_dataFileList = "/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/DataFileLists/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendY5F_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse_0.0_1.0.csv"
output_ppg_files_data = pd.read_csv(output_ppg_files_dataFileList, index_col=0)
file_paths = output_ppg_files_data['input_files'].values
file_paths = [file_path.replace('input', 'predictions') for file_path in file_paths] # Modify the file_path in file_paths by changing 'input' to 'label'
dataset = []

for file_path in file_paths:
    features = process_file(file_path)
    dataset.append(features)

df = pd.DataFrame(dataset)
df.to_csv('rppg_features_dataset.csv', index=False)
print(f"Dataset created with {len(df)} files and {len(df.columns)-1} features")
# Out:
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# ...
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# WARNING:root:HRV time features computation error: cannot convert float NaN to integer
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# Dataset created with 647 files and 26 features

# %%
# Main processing
folder_path = '/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/dummyFolder'  # Replace with your folder path
dataset = []

for file_name in os.listdir(folder_path):
    if file_name.endswith('.npy'):
        file_path = os.path.join(folder_path, file_name)
        features = process_file(file_path)
        if features:
            features['filename'] = file_name
            dataset.append(features)

df = pd.DataFrame(dataset)
df.to_csv('rppg_features_dataset.csv', index=False)
print(f"Dataset created with {len(df)} files and {len(df.columns)-1} features")
# Out:
# Dataset created with 1 files and 26 features
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 180, using nperseg = 180
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,

# %% [markdown]
# ### ***Trying to calculate hrv features***

# %%
import numpy as np
import matplotlib.pyplot as plt
import neurokit2 as nk
import pandas as pd

signal = np.load("/home/abhaygupta/workspaceVM/capstone/rPPG-Toolbox/PreprocessedData/PURE_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/206_label0.npy")
sampling_rate = 30

# # Replace signal values with 0.0 with 0.00000001
# signal = np.where(signal == 0.0, 0.0000001, signal)
# print(signal)

signals, info = nk.ppg_process(signal, sampling_rate=sampling_rate) 
peaks = info["PPG_Peaks"]
nn_intervals = np.diff(peaks) / sampling_rate * 1000 
print(peaks)
print(nn_intervals)
hrv = nk.hrv_time(info["PPG_Peaks"], sampling_rate=30, show=False)
hrv



# print(hrv.columns)
# hrv
# hrv_indices = nk.hrv_frequency(peaks, sampling_rate=sampling_rate, show=False)
# hrv_indices = nk.hrv_nonlinear(peaks, sampling_rate=sampling_rate, show=False)
# Out:
# [-7.30188277e-01 -3.68204933e-01 -3.59909481e-01 -1.80991672e-01
#  -8.29545163e-03 -1.83065535e-01  5.20162524e-01  1.94320955e+00
#   2.67754555e+00  2.26107617e+00  8.13142793e-01 -4.76611403e-01
#  -8.84219731e-01 -1.09217162e+00 -9.40214030e-01 -5.78230686e-01
#  -3.31818065e-02  1.45736003e-01 -1.06332607e-01 -3.64057207e-01
#  -6.86637156e-01 -5.45048879e-01 -7.28114414e-01 -5.45048879e-01
#  -4.13829917e-01 -3.64057207e-01 -1.80991672e-01 -5.59942985e-02
#  -1.83065535e-01  4.24764830e-01  1.56934862e+00  2.60081262e+00
#   2.86626707e+00  1.55106092e+00  3.05423447e-02 -6.55529212e-01
#  -9.11179949e-01 -9.11179949e-01 -9.11179949e-01 -4.44937860e-01
#  -1.80991672e-01 -8.50283793e-02 -3.70844395e-01 -5.45048879e-01
#  -9.11179949e-01 -5.45048879e-01 -7.28114414e-01 -6.44594299e-01
#  -5.47122742e-01 -2.84684817e-01 -1.83065535e-01 -7.52246637e-02
#  -1.80991672e-01  1.44227739e-01  1.25826919e+00  2.56819641e+00
#   3.14680416e+00  1.93114343e+00  3.60852146e-01 -4.83398591e-01
#  -7.84674311e-01 -1.09217162e+00 -9.09106086e-01 -8.08429468e-01
#  -3.15792761e-01 -4.61905830e-02 -4.08173927e-01 -7.28114414e-01
#  -7.28114414e-01 -7.28114414e-01 -7.28114414e-01 -6.94367008e-01
#  -5.47122742e-01 -3.34457527e-01 -1.83065535e-01 -1.83065535e-01
#  -1.83065535e-01 -2.04369763e-01 -1.61761307e-01  2.51691544e-01
#   1.68454228e+00  2.75748354e+00  2.87757905e+00  1.59084138e+00
#  -2.24354260e-02 -9.11179949e-01 -9.13819411e-01 -1.09160602e+00
#  -7.28114414e-01 -3.69147598e-01  1.00000000e-07 -1.75335682e-01
#  -3.64057207e-01 -7.18310698e-01 -7.28114414e-01 -7.28114414e-01
#  -7.28114414e-01 -3.82156374e-01 -5.47122742e-01 -1.80991672e-01
#  -2.07386291e-01 -1.54597053e-01 -2.84684817e-02 -1.83065535e-01
#  -1.83065535e-01  1.46301602e-01  1.30709923e+00  2.47072486e+00
#   2.91453152e+00  1.49223863e+00  1.37252018e-01 -8.64046701e-01
#  -1.04296451e+00 -1.09217162e+00 -6.53832415e-01 -2.38494235e-01
#   1.00000000e-07  1.00000000e-07 -3.02406919e-01 -5.47122742e-01
#  -6.62316400e-01 -7.28114414e-01 -6.17068482e-01 -4.73029276e-01
#  -4.38150673e-01 -1.80991672e-01 -7.82411916e-02 -1.83065535e-01
#   1.00000000e-07 -1.83065535e-01 -1.83065535e-01  2.77143498e-01
#   1.63646637e+00  2.63663389e+00  2.74013850e+00  1.48186931e+00
#  -6.71177450e-02 -7.06998719e-01 -1.01430750e+00 -9.11179949e-01
#  -8.37463549e-01 -3.64057207e-01 -1.11422998e-01  1.00000000e-07
#  -3.13907431e-01 -6.64767329e-01 -6.08395964e-01 -6.68915055e-01
#  -6.04248238e-01 -4.89997245e-01 -3.64057207e-01 -3.13153299e-01
#  -1.83065535e-01 -1.83065535e-01 -4.46823190e-02 -1.80991672e-01
#  -1.80991672e-01 -6.56094811e-02  1.05672742e+00  2.43603479e+00
#   2.91245766e+00  2.18226938e+00  4.60774632e-01 -5.73140295e-01
#  -7.52058104e-01 -9.09106086e-01 -8.89310122e-01 -7.10392313e-01
#  -3.48408969e-01 -1.35743754e-02 -3.64057207e-01 -5.37696092e-01
#  -5.63902178e-01 -7.28114414e-01 -7.24909353e-01 -5.47122742e-01
#  -3.64057207e-01 -3.64057207e-01 -1.80991672e-01 -1.80991672e-01]
# /home/abhaygupta/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/signal/signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 13
#      10 signal = np.where(signal == 0.0, 0.0000001, signal)
#      11 print(signal)
# ---> 13 signals, info = nk.ppg_process(signal, sampling_rate=sampling_rate)
#      14 peaks = info["PPG_Peaks"]
#      15 nn_intervals = np.diff(peaks) / sampling_rate * 1000
#
# File ~/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/ppg/ppg_process.py:103, in ppg_process(ppg_signal, sampling_rate, method, method_quality, report, **kwargs)
#      98 rate = signal_rate(
#      99     info["PPG_Peaks"], sampling_rate=sampling_rate, desired_length=len(ppg_cleaned)
#     100 )
#     102 # Assess signal quality
# --> 103 quality = ppg_quality(
#     104     ppg_cleaned,
#     105     ppg_pw_peaks=info["PPG_Peaks"],
#     106     sampling_rate=sampling_rate,
#     107     method=methods["method_quality"],
#     108     **methods["kwargs_quality"]
#     109 )
#     111 # Prepare output
#     112 signals = pd.DataFrame(
#     113     {
#     114         "PPG_Raw": ppg_signal,
#    (...)
#     119     }
#     120 )
#
# File ~/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/ppg/ppg_quality.py:84, in ppg_quality(ppg_cleaned, ppg_pw_peaks, sampling_rate, method, approach)
#      82 # Run selected quality assessment method
#      83 if method in ["templatematch"]:
# ---> 84     quality = _ppg_quality_templatematch(
#      85         ppg_cleaned, ppg_pw_peaks=ppg_pw_peaks, sampling_rate=sampling_rate
#      86     )
#      87 elif method in ["disimilarity"]:
#      88     quality = _ppg_quality_disimilarity(
#      89         ppg_cleaned, ppg_pw_peaks=ppg_pw_peaks, sampling_rate=sampling_rate
#      90     )
#
# File ~/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/ppg/ppg_quality.py:129, in _ppg_quality_templatematch(ppg_cleaned, ppg_pw_peaks, sampling_rate)
#     126 def _ppg_quality_templatematch(ppg_cleaned, ppg_pw_peaks=None, sampling_rate=1000):
#     127
#     128     # Obtain individual pulse waves and template pulse wave
# --> 129     templ_pw, pw_data, ppg_pw_peaks = _calc_template_pw(
#     130             ppg_cleaned, ppg_pw_peaks=ppg_pw_peaks, sampling_rate=sampling_rate
#     131         )
#     133     # Find individual correlation coefficients (CCs)
#     134     cc = np.zeros(len(ppg_pw_peaks)-1)
#
# File ~/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/ppg/ppg_quality.py:105, in _calc_template_pw(ppg_cleaned, ppg_pw_peaks, sampling_rate)
#     102     ppg_pw_peaks = ppg_pw_peaks["PPG_Peaks"]
#     104 # Get heartbeats
# --> 105 heartbeats = ppg_segment(ppg_cleaned, ppg_pw_peaks, sampling_rate)
#     106 pw_data = epochs_to_df(heartbeats).pivot(
#     107     index="Label", columns="Time", values="Signal"
#     108 )
#     109 pw_data.index = pw_data.index.astype(int)
#
# File ~/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/ppg/ppg_segment.py:63, in ppg_segment(ppg_cleaned, peaks, sampling_rate, show, **kwargs)
#      55     raise ValueError("The data length is too small to be segmented.")
#      57 epochs_start, epochs_end, average_hr = _ecg_segment_window(
#      58     rpeaks=peaks,
#      59     sampling_rate=sampling_rate,
#      60     desired_length=len(ppg_cleaned),
#      61     ratio_pre=0.3,
#      62 )
# ---> 63 heartbeats = epochs_create(
#      64     ppg_cleaned,
#      65     peaks,
#      66     sampling_rate=sampling_rate,
#      67     epochs_start=epochs_start,
#      68     epochs_end=epochs_end,
#      69 )
#      71 # pad last heartbeat with nan so that segments are equal length
#      72 last_heartbeat_key = str(np.max(np.array(list(heartbeats.keys()), dtype=int)))
#
# File ~/.conda/envs/rSPO2/lib/python3.10/site-packages/neurokit2/epochs/epochs_create.py:164, in epochs_create(data, events, sampling_rate, epochs_start, epochs_end, event_labels, event_conditions, baseline_correction)
#     162 # Find the maximum numbers of samples in an epoch
#     163 parameters["duration"] = list(np.array(parameters["end"]) - np.array(parameters["start"]))
# --> 164 epoch_max_duration = int(max((i * sampling_rate for i in parameters["duration"])))
#     166 # Extend data by the max samples in epochs * NaN (to prevent non-complete data)
#     167 length_buffer = epoch_max_duration
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# ### ***Read csv and extract ground truth spo2 values***

# %%
import pandas as pd
import numpy as np
import os

# Load the dataset - make sure the path is correct
file_path = 'rppg_features_dataset.csv'  # Adjust path if needed
df = pd.read_csv(file_path)

# Function to extract spo2 values from the modified file path
def extract_spo2_from_path(path):
    # Replace 'label' with 'spo2' in the filename
    spo2_path = path.replace('_predictions', '_spo2')
    try:
        # Load the numpy array from the spo2 file
        spo2_values = np.load(spo2_path)
        # Calculate mean spo2 value
        mean_spo2 = np.mean(spo2_values)
        return mean_spo2
    except Exception as e:
        print(f"Error loading {spo2_path}: {e}")
        return np.nan

# Apply the function to extract ground truth spo2 values
df['ground_truth_spo2'] = df['filename'].apply(extract_spo2_from_path)

# Save the updated dataframe with ground truth values
output_file_path = 'rppg_features_dataset_with_spo2.csv'
df.to_csv(output_file_path, index=False)

# Display basic statistics of the ground truth values
spo2_stats = df['ground_truth_spo2'].describe()
print("SpO2 Ground Truth Statistics:")
print(spo2_stats)

# Check for missing values
missing_spo2 = df['ground_truth_spo2'].isna().sum()
print(f"Number of missing SpO2 values: {missing_spo2}")
# Out:
# SpO2 Ground Truth Statistics:
# count    647.000000
# mean      97.093968
# std        1.666053
# min       89.666667
# 25%       96.000000
# 50%       97.579262
# 75%       98.419052
# max       99.000000
# Name: ground_truth_spo2, dtype: float64
# Number of missing SpO2 values: 0
